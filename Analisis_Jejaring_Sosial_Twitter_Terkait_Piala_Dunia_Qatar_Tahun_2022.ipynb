# %% [markdown]
# <a href="https://colab.research.google.com/github/dellaar/Della_Portofolio/blob/main/Analisis_Jejaring_Sosial_Twitter_Terkait_Piala_Dunia_Qatar_Tahun_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Akhir Data Mining Kelompok 5**
# ##**Analisis jejaring sosial twitter terkait piala dunia Qatar 2022**

# %% [markdown]
# ##**Install dan Import Library**

# %% [markdown]
# *   NLTK
#
# NLTK (Natural Language Toolkit) menyediakan berbagai macam fungsi dan alat yang dapat digunakan dalam pemrosesan bahasa alami.
#
# *   Sastrawi
#
# Sastrawi adalah library Python yang digunakan untuk melakukan stemming bahasa Indonesia. Stemming adalah proses menghilangkan imbuhan pada kata sehingga kata tersebut kembali ke kata dasar (root word). Misalnya, kata "memakan" akan diubah menjadi "makan" setelah melalui proses stemming.
#
# *   Pandas
#
# Pandas adalah library Python yang banyak digunakan untuk mengelola dan menganalisis data.

# %%
# !pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import string
import re
import matplotlib.pyplot as plt
import csv

# %%
import nltk
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ##**Import Data CSV**

# %%
import warnings; warnings.simplefilter('ignore')

try:
    import google.colab; IN_COLAB = True
    print("Installing the required modules")
    # !pip install --upgrade umap-learn
    # !wget https://github.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/blob/main/Data_Twitter_Pildun.csv
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")
# Out:
# Installing the required modules
# Collecting umap-learn
#   Downloading umap-learn-0.5.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (2021.10.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn) (0.41.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.4-py3-none-any.whl size=86770 sha256=51f2e708b9532f1aa8b2d0194dcac4ff20c4c2375bc5f295b6253ee6a9fa5f91
#   Stored in directory: /root/.cache/pip/wheels/fb/66/29/199acf5784d0f7b8add6d466175ab45506c96e386ed5dd0633
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=eb16c454ed5865a1514ed6290c1bbbff7017ab37546da8a070ab692a90c5beb8
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.10 umap-learn-0.5.4
# --2023-11-16 14:28:40--  https://github.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/blob/main/Data_Twitter_Pildun.csv
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5312 (5.2K) [text/plain]
# Saving to: ‘Data_Twitter_Pildun.csv’
#
# Data_Twitter_Pildun 100%[===================>]   5.19K  --.-KB/s    in 0s
#
# 2023-11-16 14:28:40 (62.5 MB/s) - ‘Data_Twitter_Pildun.csv’ saved [5312/5312]

# %%
url_data = (r'https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/Data_Twitter_Pildun.csv')

# %%
df = pd.read_csv(url_data)
df
# Out:
#                        id      conversation_id               created_at  \
# 0     1608137397375766529  1608137397375766529  2022-12-28 16:26:47 UTC
# 1     1608118257361518596  1608118257361518596  2022-12-28 15:10:44 UTC
# 2     1608114838815010817  1608114838815010817  2022-12-28 14:57:09 UTC
# 3     1608112598410743814  1608112598410743814  2022-12-28 14:48:15 UTC
# 4     1608111124670709762  1608111124670709762  2022-12-28 14:42:24 UTC
# ...                   ...                  ...                      ...
# 2654  1604539206076108802  1604539206076108802  2022-12-18 18:08:52 UTC
# 2655  1604539185859215361  1604539185859215361  2022-12-18 18:08:47 UTC
# 2656  1604539121526939649  1604539121526939649  2022-12-18 18:08:32 UTC
# 2657  1604539090158096384  1604539090158096384  2022-12-18 18:08:24 UTC
# 2658  1604539089054683136  1604539089054683136  2022-12-18 18:08:24 UTC
#
#             date      time  timezone              user_id         username  \
# 0     2022-12-28  16:26:47         0  1222927522033094656      idextratime
# 1     2022-12-28  15:10:44         0   734582844685705218            58o94
# 2     2022-12-28  14:57:09         0   945591801330597892   harus_kamutahu
# 3     2022-12-28  14:48:15         0   740603423079288832  gusyusufchannel
# 4     2022-12-28  14:42:24         0             36205934   abuv_average88
# ...          ...       ...       ...                  ...              ...
# 2654  2022-12-18  18:08:52         0            142537012    adjie_djithuu
# 2655  2022-12-18  18:08:47         0   926487776081539072     skandalmedia
# 2656  2022-12-18  18:08:32         0            288147069         haijoon_
# 2657  2022-12-18  18:08:24         0  1433831856986738690  andreasyona1601
# 2658  2022-12-18  18:08:24         0             38822788      adliazman__
#
#                                    name place  ... geo source user_rt_id  \
# 0                  Extra Time Indonesia   NaN  ... NaN    NaN        NaN
# 1                                     ★   NaN  ... NaN    NaN        NaN
# 2                       Harus kamu tahu   NaN  ... NaN    NaN        NaN
# 3                     Gus Yusuf Channel   NaN  ... NaN    NaN        NaN
# 4                        Victoria Trice   NaN  ... NaN    NaN        NaN
# ...                                 ...   ...  ...  ..    ...        ...
# 2654                      Aji Widayanto   NaN  ... NaN    NaN        NaN
# 2655  #LawanPropaganda🏴⭐️SkandalMedia⭐️   NaN  ... NaN    NaN        NaN
# 2656                   karan⁷🌻 indigo 💙   NaN  ... NaN    NaN        NaN
# 2657                              Andre   NaN  ... NaN    NaN        NaN
# 2658                                 AA   NaN  ... NaN    NaN        NaN
#
#      user_rt retweet_id  reply_to  retweet_date  translate trans_src  \
# 0        NaN        NaN        []           NaN        NaN       NaN
# 1        NaN        NaN        []           NaN        NaN       NaN
# 2        NaN        NaN        []           NaN        NaN       NaN
# 3        NaN        NaN        []           NaN        NaN       NaN
# 4        NaN        NaN        []           NaN        NaN       NaN
# ...      ...        ...       ...           ...        ...       ...
# 2654     NaN        NaN        []           NaN        NaN       NaN
# 2655     NaN        NaN        []           NaN        NaN       NaN
# 2656     NaN        NaN        []           NaN        NaN       NaN
# 2657     NaN        NaN        []           NaN        NaN       NaN
# 2658     NaN        NaN        []           NaN        NaN       NaN
#
#      trans_dest
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2654        NaN
# 2655        NaN
# 2656        NaN
# 2657        NaN
# 2658        NaN
#
# [2659 rows x 36 columns]

# %%
# Menampilkan data dari table username dan tweet
df[['username', 'tweet']]
# Out:
#              username                                              tweet
# 0         idextratime  Qatar University mengumumkan kamar yang ditemp...
# 1               58o94  Puan Maharani berharap gelaran Piala Dunia 202...
# 2      harus_kamutahu  #youtube 8 stadion mewah dan canggih Piala Dun...
# 3     gusyusufchannel  KH. Chudlori, Gus Dur dan Piala Dunia Qatar 20...
# 4      abuv_average88  Puan Maharani berharap gelaran Piala Dunia 202...
# ...               ...                                                ...
# 2654    adjie_djithuu  Final sangat istimewa Piala Dunia Qatar 2022. ...
# 2655     skandalmedia  😎 akhirnya tumbang juga pendukung pelangi bute...
# 2656         haijoon_  Digadang jadi piala dunia paling sunyi karna b...
# 2657  andreasyona1601  Selamat kepada Argentina atas kemenangannya di...
# 2658      adliazman__  Argentina dan Lionel Messi tidak lagi menangis...
#
# [2659 rows x 2 columns]

# %% [markdown]
# #**Text Preprocessing**

# %% [markdown]
# Text preprocessing adalah suatu proses untuk menyeleksi data text agar menjadi lebih terstruktur lagi dengan melalui serangkaian tahapan yang meliputi tahapan text, cleaning, case folding, tokenizing, stopword dan stemming.

# %% [markdown]
# ## **Text Cleaning**
# Proses membersihkan
# dokumen dari komponen-komponen
# yang tidak memiliki hubungan dengan
# informasi yang ada pada dokumen,
# seperti tag html, link, emoji, angka, dll.

# %%
def remove_char_special(text):
    # menghapus tab dan baris baru
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # menghapus emoticon
    text = text.encode('ascii', 'replace').decode('ascii')
    # menghapus mention, link, dan hastag
    text = ' '.join(re.sub("([@#][A-Za-z]+)|(\w+:\/\/\S+)"," ", text).split())
    # menghapus url
    return text.replace("http://", " ").replace("https://", " ")

def remove_punctuation(text):
    return text.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation)))

def remove_number(text):
    return re.sub(r"[0-9]", "", text)

def remove_whitespace(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

# %% [markdown]
# Dari code diatas, dilakukan:
# 1. Penghapusan tab dan baris baru
#
# 2. Penghapusan emoticon.
#
# 3. Penghapusan mention, link, dan hastag.
#
# 4. Penghapusan url.
#
# Fungsi ini berguna untuk membersihkan tweet sebelum dilakukan analisis terhadap tweet tersebut. Dengan membersihkan tweet terlebih dahulu, hasil analisis akan lebih akurat karena tidak terdistorsi oleh tanda baca, karakter lain, dan sebagainya.

# %%
df['data_bersih'] = df['tweet']

# %%
df['data_bersih'] = df['data_bersih'].apply(remove_char_special)
df['data_bersih'] = df['data_bersih'].apply(remove_punctuation)
df['data_bersih'] = df['data_bersih'].apply(remove_number)
df['data_bersih'] = df['data_bersih'].apply(remove_whitespace)
df['data_bersih'] = df['data_bersih'].apply(remove_whitespace_multiple)

# %% [markdown]
# **Perbedaan sebelum dan sesudah text cleaning**

# %%
df[['tweet','data_bersih']]
# Out:
#                                                   tweet  \
# 0     Qatar University mengumumkan kamar yang ditemp...
# 1     Puan Maharani berharap gelaran Piala Dunia 202...
# 2     #youtube 8 stadion mewah dan canggih Piala Dun...
# 3     KH. Chudlori, Gus Dur dan Piala Dunia Qatar 20...
# 4     Puan Maharani berharap gelaran Piala Dunia 202...
# ...                                                 ...
# 2654  Final sangat istimewa Piala Dunia Qatar 2022. ...
# 2655  😎 akhirnya tumbang juga pendukung pelangi bute...
# 2656  Digadang jadi piala dunia paling sunyi karna b...
# 2657  Selamat kepada Argentina atas kemenangannya di...
# 2658  Argentina dan Lionel Messi tidak lagi menangis...
#
#                                             data_bersih
# 0     Qatar University mengumumkan kamar yang ditemp...
# 1     Puan Maharani berharap gelaran Piala Dunia yan...
# 2     stadion mewah dan canggih Piala Dunia Qatar Ib...
# 3     KH Chudlori Gus Dur dan Piala Dunia Qatar Gus ...
# 4     Puan Maharani berharap gelaran Piala Dunia yan...
# ...                                                 ...
# 2654  Final sangat istimewa Piala Dunia Qatar Selama...
# 2655  akhirnya tumbang juga pendukung pelangi butex ...
# 2656  Digadang jadi piala dunia paling sunyi karna b...
# 2657  Selamat kepada Argentina atas kemenangannya di...
# 2658  Argentina dan Lionel Messi tidak lagi menangis...
#
# [2659 rows x 2 columns]

# %% [markdown]
# ##**1. Case Folding**
#
# Digunakan untuk menyamaratakan huruf kecil dan huruf kapital agar lebih mudah dianalisis. Akan dilakukan pengubahan huruf kapital menjadi huruf kecil.

# %%
df['data_lower'] = df['data_bersih'].str.lower()

# %% [markdown]
# **Perbedaan sebelum dan sesudah case folding**

# %%
df[["data_bersih", "data_lower"]]
# Out:
#                                             data_bersih  \
# 0     Qatar University mengumumkan kamar yang ditemp...
# 1     Puan Maharani berharap gelaran Piala Dunia yan...
# 2     stadion mewah dan canggih Piala Dunia Qatar Ib...
# 3     KH Chudlori Gus Dur dan Piala Dunia Qatar Gus ...
# 4     Puan Maharani berharap gelaran Piala Dunia yan...
# ...                                                 ...
# 2654  Final sangat istimewa Piala Dunia Qatar Selama...
# 2655  akhirnya tumbang juga pendukung pelangi butex ...
# 2656  Digadang jadi piala dunia paling sunyi karna b...
# 2657  Selamat kepada Argentina atas kemenangannya di...
# 2658  Argentina dan Lionel Messi tidak lagi menangis...
#
#                                              data_lower
# 0     qatar university mengumumkan kamar yang ditemp...
# 1     puan maharani berharap gelaran piala dunia yan...
# 2     stadion mewah dan canggih piala dunia qatar ib...
# 3     kh chudlori gus dur dan piala dunia qatar gus ...
# 4     puan maharani berharap gelaran piala dunia yan...
# ...                                                 ...
# 2654  final sangat istimewa piala dunia qatar selama...
# 2655  akhirnya tumbang juga pendukung pelangi butex ...
# 2656  digadang jadi piala dunia paling sunyi karna b...
# 2657  selamat kepada argentina atas kemenangannya di...
# 2658  argentina dan lionel messi tidak lagi menangis...
#
# [2659 rows x 2 columns]

# %% [markdown]
# ##**2. Text Normalization: Slang Words**
#
# Dilakukan untuk mengubah kata-kata slang atau gaul dalam teks menjadi bentuk yang lebih mudah dianalisis.

# %%
# !wget https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/slang.txt -O slang.txt
# Out:
# --2023-11-16 14:28:41--  https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/slang.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1869 (1.8K) [text/plain]
# Saving to: ‘slang.txt’
#
# slang.txt           100%[===================>]   1.83K  --.-KB/s    in 0s
#
# 2023-11-16 14:28:41 (25.3 MB/s) - ‘slang.txt’ saved [1869/1869]

# %%
fSlang = 'slang.txt'
bahasa = 'id'
sw=open(fSlang,encoding='utf-8', errors='ignore', mode='r');SlangS=sw.readlines();sw.close()
SlangS = {slang.strip().split(':')[0]:slang.strip().split(':')[1] for slang in SlangS}

# %%
# List slang
SlangS
# Out:
# {'bbrp': 'beberapa',
#  'gud': 'bagus',
#  'laen': 'lain',
#  'nich': 'ini',
#  'gk': 'tidak',
#  'baguss': 'bagus',
#  'bgt': 'banget',
#  'spy': 'supaya',
#  'trima': 'terima',
#  'nyampe': 'sampai',
#  'make': 'pakai',
#  'mendonlod': 'mengunduh',
#  'lbh': 'lebih',
#  'gini': 'begini',
#  'lg': 'lagi',
#  'ok': 'oke',
#  'permbayaran': 'pembayaran',
#  'min': 'admin',
#  'trmkasih': 'terima kasih',
#  'pantes': 'pantas',
#  'sy': 'saya',
#  'bs': 'bisa',
#  'pdhl': 'padahal',
#  'smpai': 'sampai',
#  'brp': 'berapa',
#  'pasword': 'password',
#  'paoword': 'password',
#  'refeera': 'referal',
#  'ngaktifin': 'aktifin',
#  'applikasi': 'aplikasi',
#  'byar': 'bayar',
#  'bajet': 'biaya',
#  'aj': 'saja',
#  'rp': 'rupiah',
#  'brhasil': 'berhasil',
#  'kpotong': 'kepotong',
#  'kmana': 'kemana',
#  'bgttt': 'banget',
#  'sampek': 'sampai',
#  'gada': 'tidak ada',
#  'lbih': 'lebih',
#  'hrus': 'harus',
#  'ngak': 'tidak',
#  'tp': 'tapi',
#  'sja': 'saja',
#  'utuk': 'untuk',
#  'jt': 'juta',
#  'maintence': 'maintenance',
#  'passwors': 'password',
#  'androit': 'android',
#  'mantaap': 'mantap',
#  'pokokny': 'pokoknya',
#  'ajah': 'saja',
#  'ywh': 'yaudah',
#  'ngabisa': 'tidak bisa',
#  'ngirim': 'mengirim',
#  'apah': 'apa',
#  'nyari': 'mencari',
#  'kmn': 'kemana',
#  'tlng': 'tolong',
#  'donk': 'dong',
#  'mn': 'mana',
#  'bkn': 'bukan',
#  'ksh': 'kasih',
#  'bukak': 'buka',
#  'skrg': 'sekarang',
#  'nggk': 'tidak',
#  'bberapa': 'beberapa',
#  'tpi': 'tapi',
#  'dpt': 'dapat',
#  'gaak': 'tidak',
#  'sippppp': 'sip',
#  'jg': 'juga',
#  'ni': 'ini',
#  'gabisa': 'tidak bisa',
#  'ngisi': 'isi',
#  'gx': 'tidak',
#  'pswd': 'password',
#  'gmna': 'gimana',
#  'soalx': 'soalnya',
#  'jelekkk': 'jelek',
#  'sdah': 'sudah',
#  'nggak': 'tidak',
#  'trus': 'terus',
#  'kyk': 'kayak',
#  'pbyaran': 'pembayaran',
#  'semuax': 'semuanya',
#  'dirumh': 'dirumah',
#  'nda': 'tidak',
#  'jlek': 'jelek',
#  'mw': 'mau',
#  'kudu': 'harus',
#  'gw': 'saya',
#  'sllu': 'selalu',
#  'jngan': 'jangan',
#  'bagua': 'bagus',
#  'nyusahin': 'menyusahkan',
#  'setwlah': 'setelah',
#  'krna': 'karena',
#  'sprti': 'seperti',
#  'sma': 'sama',
#  'aq': 'saya',
#  'dlu': 'dulu',
#  'ja': 'saja',
#  'sgr': 'segera',
#  'aplikasix': 'aplikasinya',
#  'tros': 'terus',
#  'cmn': 'cuma',
#  'tlg': 'tolong',
#  'donlod': 'download',
#  'pdahal': 'padahal',
#  'ajj': 'saja',
#  'kmrin': 'kemarin',
#  'sgala': 'segala',
#  'knapa': 'kenapa',
#  'dtg': 'datang',
#  'lgi': 'lagi',
#  'iy': 'iya',
#  'sabi': 'bisa',
#  'jgan': 'jangan',
#  'bnyk': 'banyak',
#  'bkin': 'bikin',
#  'plit': 'pelit',
#  'gax': 'tidak',
#  'yh': 'iya',
#  'tlpn': 'telepon',
#  'slh': 'salah',
#  'ad': 'ada',
#  'dlm': 'dalam',
#  'sampe': 'sampai',
#  'kaga': 'tidak',
#  'pa': 'apa',
#  'ywdh': 'yaudah',
#  'ttp': 'tetap',
#  'trimakasih': 'terima kasih',
#  'lwt': 'lewat',
#  'mantapz': 'mantap',
#  'jgn': 'jangan',
#  'blg': 'bilang'}

# %%
def slang(t):
  t = word_tokenize(t)
  for i, x in enumerate(t):
    if x in SlangS.keys():
      t[i] = SlangS[x]
  return ''.join(' '.join(x for x in t if x not in ""))

# %%
data = [x for x in df['data_lower']]

# %%
replace_slangs = list(map(slang, data))

# %%
df['data_setelah_slang'] = replace_slangs

# %% [markdown]
# ##**Tokenize**
# Digunakan untuk memisahkan teks menjadi potongan-potongan berupa token, misalnya berupa potongan huruf, kata, atau kalimat.

# %%
df['data_token'] = df['data_setelah_slang'].apply(nltk.word_tokenize)

# %%
df[['data_setelah_slang','data_token']]
# Out:
#                                      data_setelah_slang  \
# 0     qatar university mengumumkan kamar yang ditemp...
# 1     puan maharani berharap gelaran piala dunia yan...
# 2     stadion mewah dan canggih piala dunia qatar ib...
# 3     kh chudlori gus dur dan piala dunia qatar gus ...
# 4     puan maharani berharap gelaran piala dunia yan...
# ...                                                 ...
# 2654  final sangat istimewa piala dunia qatar selama...
# 2655  akhirnya tumbang juga pendukung pelangi butex ...
# 2656  digadang jadi piala dunia paling sunyi karna b...
# 2657  selamat kepada argentina atas kemenangannya di...
# 2658  argentina dan lionel messi tidak lagi menangis...
#
#                                              data_token
# 0     [qatar, university, mengumumkan, kamar, yang, ...
# 1     [puan, maharani, berharap, gelaran, piala, dun...
# 2     [stadion, mewah, dan, canggih, piala, dunia, q...
# 3     [kh, chudlori, gus, dur, dan, piala, dunia, qa...
# 4     [puan, maharani, berharap, gelaran, piala, dun...
# ...                                                 ...
# 2654  [final, sangat, istimewa, piala, dunia, qatar,...
# 2655  [akhirnya, tumbang, juga, pendukung, pelangi, ...
# 2656  [digadang, jadi, piala, dunia, paling, sunyi, ...
# 2657  [selamat, kepada, argentina, atas, kemenangann...
# 2658  [argentina, dan, lionel, messi, tidak, lagi, m...
#
# [2659 rows x 2 columns]

# %% [markdown]
# ### **Melihat Frekuensi Kata**

# %%
list_to_text = ' '.join([i for i in df['data_setelah_slang']])

# %%
tokenized_words = nltk.tokenize.word_tokenize(list_to_text)

# %%
frekuensi_tokens = nltk.FreqDist(tokenized_words)
print('Frekuensi Tokens : \n')
print (frekuensi_tokens.most_common())
# Out:
# Frekuensi Tokens :
#
# [('dunia', 2797), ('piala', 2728), ('qatar', 2204), ('di', 1398), ('argentina', 1158), ('yang', 739), ('juara', 677), ('messi', 660), ('dan', 572), ('final', 420), ('dari', 344), ('ini', 329), ('prancis', 325), ('lionel', 310), ('stadion', 281), ('menjadi', 255), ('dengan', 237), ('terbaik', 227), ('untuk', 208), ('jadi', 202), ('timnas', 194), ('pemain', 191), ('fifa', 177), ('usai', 172), ('pada', 172), ('setelah', 168), ('mbappe', 167), ('sebagai', 165), ('selamat', 161), ('tahun', 152), ('dalam', 152), ('cup', 145), ('bola', 142), ('gol', 141), ('world', 136), ('trofi', 132), ('yg', 129), ('berhasil', 128), ('ada', 126), ('adu', 126), ('sudah', 121), ('tim', 119), ('pertandingan', 116), ('itu', 115), ('ke', 115), ('dibuat', 110), ('bahan', 108), ('bekas', 108), ('mewah', 103), ('canggih', 103), ('penalti', 102), ('telah', 99), ('kemenangan', 97), ('negara', 95), ('bisa', 94), ('indonesia', 92), ('sepak', 92), ('desember', 86), ('juga', 86), ('gelar', 84), ('tidak', 83), ('vs', 82), ('saat', 82), ('banyak', 81), ('nonton', 80), ('lusail', 80), ('sepanjang', 80), ('selama', 76), ('adalah', 76), ('pildun', 76), ('sejarah', 75), ('mengalahkan', 75), ('akan', 74), ('sukses', 74), ('hari', 74), ('minggu', 73), ('bersama', 73), ('kylian', 71), ('amp', 71), ('para', 71), ('menang', 71), ('sampai', 70), ('ronaldo', 68), ('rumah', 68), ('perancis', 68), ('tak', 67), ('buat', 66), ('kepada', 66), ('satu', 66), ('tapi', 66), ('kali', 65), ('drama', 64), ('jubah', 64), ('saya', 63), ('resmi', 62), ('atas', 62), ('laga', 61), ('lewat', 61), ('akhirnya', 61), ('tuan', 60), ('the', 60), ('hingga', 59), ('akhir', 58), ('arab', 57), ('momen', 57), ('lagi', 56), ('antara', 56), ('martinez', 56), ('membawa', 56), ('kasih', 56), ('berakhir', 55), ('malam', 55), ('karena', 54), ('terima', 54), ('berikut', 53), ('skor', 53), ('sports', 52), ('rekor', 52), ('salah', 52), ('paling', 52), ('faisol', 52), ('ali', 52), ('ibu', 51), ('mirip', 51), ('maroko', 51), ('pemenang', 51), ('bawa', 51), ('nobar', 51), ('mereka', 49), ('presiden', 49), ('hal', 48), ('menarik', 48), ('pertama', 48), ('top', 47), ('hobi', 47), ('oleh', 47), ('dia', 46), ('nia', 45), ('ramadhani', 45), ('sangat', 45), ('hadiah', 45), ('hanya', 44), ('bagi', 44), ('kalah', 44), ('sama', 44), ('media', 43), ('ya', 43), ('dapat', 42), ('bukan', 42), ('lebih', 41), ('meraih', 41), ('goat', 41), ('penghargaan', 41), ('sepakbola', 40), ('selengkapnya', 40), ('menjuarai', 40), ('pun', 40), ('pernah', 40), ('pelatih', 40), ('prediksi', 39), ('emas', 39), ('baru', 39), ('ternyata', 38), ('atau', 38), ('sulbar', 38), ('gelaran', 37), ('masih', 37), ('berita', 37), ('daftar', 37), ('luar', 37), ('mengangkat', 37), ('keluar', 37), ('tampil', 36), ('bisht', 36), ('memenangkan', 36), ('biasa', 36), ('tersebut', 35), ('islam', 35), ('jangan', 35), ('sang', 35), ('masuk', 34), ('kota', 34), ('emiliano', 34), ('emir', 34), ('angkat', 34), ('rakyat', 33), ('orang', 33), ('apa', 33), ('sejak', 33), ('liga', 33), ('muda', 33), ('turnamen', 33), ('maradona', 33), ('masa', 33), ('amerika', 32), ('udah', 32), ('fans', 32), ('seru', 32), ('terbanyak', 32), ('foto', 32), ('raih', 32), ('of', 32), ('berlangsung', 31), ('link', 31), ('pinalti', 31), ('nya', 31), ('secara', 31), ('stadium', 31), ('namun', 31), ('kami', 31), ('a', 31), ('babak', 31), ('siapa', 30), ('saja', 30), ('memiliki', 30), ('melalui', 30), ('nasional', 30), ('cetak', 30), ('golden', 30), ('bareng', 30), ('kakanwil', 30), ('tetap', 29), ('aja', 29), ('keberhasilan', 29), ('kembali', 29), ('banget', 29), ('merayakan', 29), ('via', 29), ('ketiga', 29), ('benar', 29), ('time', 29), ('tanpa', 28), ('awal', 28), ('kedua', 28), ('bintang', 28), ('bahwa', 28), ('partai', 28), ('inggris', 28), ('beberapa', 28), ('kita', 28), ('gagal', 27), ('sekarang', 27), ('ajang', 27), ('semua', 27), ('membuat', 27), ('sri', 26), ('mulyani', 26), ('mama', 26), ('awards', 26), ('terakhir', 26), ('rupiah', 26), ('pesta', 26), ('selebrasi', 26), ('langsung', 26 ...

# %% [markdown]
# ##**3. Text Level Normalization: StopWords**
#
# Digunakan untuk menghilangkan stopwords (kata yang sering muncul dalam teks) tetapi tidak memiliki arti.

# %%
from nltk.corpus import stopwords

# %%
# !wget https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/stopword.txt -O stopword.txt
# Out:
# --2023-11-16 14:28:42--  https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/stopword.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7203 (7.0K) [text/plain]
# Saving to: ‘stopword.txt’
#
# stopword.txt        100%[===================>]   7.03K  --.-KB/s    in 0s
#
# 2023-11-16 14:28:43 (59.1 MB/s) - ‘stopword.txt’ saved [7203/7203]

# %%
list_stopwords = stopwords.words('indonesian')

txt_stopword = pd.read_csv("stopword.txt", names= ["stopwords"], header = None)

# Convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))


list_stopwords.extend(["tq","yg", "dg", "rt", "dgn", "ny", "d", 'klo',
                       'kalo', 'amp', 'biar', 'bikin', 'bilang',
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih',
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya',
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't',
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah','hr','rb'])


# Convert list to dictionary
list_stopwords = set(list_stopwords)

# Remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

# %%
df['data_stopwords'] = df['data_token'].apply(stopwords_removal)

df[['data_token','data_stopwords']]
# Out:
#                                              data_token  \
# 0     [qatar, university, mengumumkan, kamar, yang, ...
# 1     [puan, maharani, berharap, gelaran, piala, dun...
# 2     [stadion, mewah, dan, canggih, piala, dunia, q...
# 3     [kh, chudlori, gus, dur, dan, piala, dunia, qa...
# 4     [puan, maharani, berharap, gelaran, piala, dun...
# ...                                                 ...
# 2654  [final, sangat, istimewa, piala, dunia, qatar,...
# 2655  [akhirnya, tumbang, juga, pendukung, pelangi, ...
# 2656  [digadang, jadi, piala, dunia, paling, sunyi, ...
# 2657  [selamat, kepada, argentina, atas, kemenangann...
# 2658  [argentina, dan, lionel, messi, tidak, lagi, m...
#
#                                          data_stopwords
# 0     [qatar, university, mengumumkan, kamar, ditemp...
# 1     [puan, maharani, berharap, gelaran, piala, dun...
# 2     [stadion, mewah, canggih, piala, dunia, qatar,...
# 3     [kh, chudlori, gus, dur, piala, dunia, qatar, ...
# 4     [puan, maharani, berharap, gelaran, piala, dun...
# ...                                                 ...
# 2654  [final, istimewa, piala, dunia, qatar, selamat...
# 2655  [tumbang, pendukung, pelangi, butex, en, islam...
# 2656  [digadang, piala, dunia, sunyi, karna, kontrov...
# 2657  [selamat, argentina, kemenangannya, piala, dun...
# 2658  [argentina, lionel, messi, menangis, selepas, ...
#
# [2659 rows x 2 columns]

# %% [markdown]
# **Menghapus list yang kosong dari kolom data_stopwords**

# %%
df = df[df.astype(str)['data_stopwords'] != '[]']

# %%
df[['data_token','data_stopwords']]
# Out:
#                                              data_token  \
# 0     [qatar, university, mengumumkan, kamar, yang, ...
# 1     [puan, maharani, berharap, gelaran, piala, dun...
# 2     [stadion, mewah, dan, canggih, piala, dunia, q...
# 3     [kh, chudlori, gus, dur, dan, piala, dunia, qa...
# 4     [puan, maharani, berharap, gelaran, piala, dun...
# ...                                                 ...
# 2654  [final, sangat, istimewa, piala, dunia, qatar,...
# 2655  [akhirnya, tumbang, juga, pendukung, pelangi, ...
# 2656  [digadang, jadi, piala, dunia, paling, sunyi, ...
# 2657  [selamat, kepada, argentina, atas, kemenangann...
# 2658  [argentina, dan, lionel, messi, tidak, lagi, m...
#
#                                          data_stopwords
# 0     [qatar, university, mengumumkan, kamar, ditemp...
# 1     [puan, maharani, berharap, gelaran, piala, dun...
# 2     [stadion, mewah, canggih, piala, dunia, qatar,...
# 3     [kh, chudlori, gus, dur, piala, dunia, qatar, ...
# 4     [puan, maharani, berharap, gelaran, piala, dun...
# ...                                                 ...
# 2654  [final, istimewa, piala, dunia, qatar, selamat...
# 2655  [tumbang, pendukung, pelangi, butex, en, islam...
# 2656  [digadang, piala, dunia, sunyi, karna, kontrov...
# 2657  [selamat, argentina, kemenangannya, piala, dun...
# 2658  [argentina, lionel, messi, menangis, selepas, ...
#
# [2655 rows x 2 columns]

# %% [markdown]
# ##**4. Stemming**
#
# Digunakan untuk menghilangkan imbuhan pada akhir kata agar lebih mudah dianalisis.

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
def stemmed(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['data_stopwords']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")
# Out:
# 4960
# ------------------------
# qatar : qatar
# university : university
# mengumumkan : umum
# kamar : kamar
# ditempati : tempat
# lionel : lionel
# messi : messi
# gelaran : gelar
# piala : piala
# dunia : dunia
# diubah : ubah
# museum : museum
# mini : mini
# kampus : kampus
# kamp : kamp
# timnas : timnas
# argentina : argentina
# kemarin : kemarin
# puan : puan
# maharani : maharani
# berharap : harap
# berjalan : jalan
# lancar : lancar
# harapan : harap
# rakyat : rakyat
# stadion : stadion
# mewah : mewah
# canggih : canggih
# sri : sri
# mulyani : mulyani
# mama : mama
# awards : awards
# kh : kh
# chudlori : chudlori
# gus : gus
# dur : dur
# ch : ch
# youtube : youtube
# kylian : kylian
# mbappe : mbappe
# bangkit : bangkit
# gagal : gagal
# doooooooong : doooooooong
# admin : admin
# saksi : saksi
# bisu : bisu
# disulap : sulap
# pengelola : kelola
# mess : mess
# basecamp : basecamp
# menjadikan : jadi
# leo : leo
# yup : yup
# gambaran : gambar
# sejarah : sejarah
# kabarnya : kabar
# barat : barat
# fenomena : fenomena
# orang : orang
# beli : beli
# bidet : bidet
# semprotan : semprot
# pulang : pulang
# pasca : pasca
# nonton : nonton
# pencetak : cetak
# gol : gol
# tertua : tua
# sajakah : saja
# ronaldo : ronaldo
# sports : sports
# masuk : masuk
# akal : akal
# fifa : fifa
# atur : atur
# juara : juara
# terbaik : baik
# prediksi : prediksi
# aff : aff
# indonesia : indonesia
# vs : vs
# thailand : thailand
# desember : desember
# link : link
# claim : claim
# bonus : bonus
# deposit : deposit
# k : k
# pulsa : pulsa
# potongan : potong
# dewa : dewa
# hotel : hotel
# kapten : kapten
# menginap : inap
# dijadikan : jadi
# wni : wni
# volunteer : volunteer
# duta : duta
# bangsa : bangsa
# tweet : tweet
# pinalti : pinalti
# prancis : prancis
# bapuk : bapuk
# diselenggarakan : selenggara
# kesalahan : salah
# mas : mas
# gibran : gibran
# bahan : bahan
# bekas : bekas
# baifern : baifern
# pengendalian : kendali
# imei : imei
# giliran : gilir
# amerika : amerika
# syarikat : syarikat
# tuan : tuan
# rumah : rumah
# lantang : lantang
# memburukkan : buruk
# tandingi : tanding
# rekod : rekod
# besaran : besar
# gaji : gaji
# congratulations : congratulations
# berhasil : hasil
# mnjdi : mnjdi
# world : world
# cup : cup
# vamous : vamous
# dn : dn
# sukses : sukses
# pemain : main
# dipulangkannya : pulang
# benzema : benzema
# jelang : jelang
# laga : laga
# perdana : perdana
# memicu : picu
# polemik : polemik
# dinobatkan : nobat
# abad : abad
# ayam : ayam
# burger : burger
# king : king
# terpilihnya : pilih
# menimbulkan : timbul
# publik : publik
# pasalnya : pasal
# catatan : catat
# buruk : buruk
# terkait : kait
# isu : isu
# hak : hak
# asasi : asasi
# manusia : manusia
# terpilih : pilih
# ubah : ubah
# bertahap : tahap
# kelayakan : layak
# asia : asia
# berasingan : asing
# digabungkan : gabung
# rantau : rantau
# bersaing : saing
# peringkat : peringkat
# benua : benua
# top : top
# idea : idea
# terpulang : pulang
# badan : badan
# bolasepak : bolasepak
# jurang : jurang
# dirapatkan : rapat
# buktikan : bukti
# nia : nia
# ramadhani : ramadhani
# hobi : hobi
# voting : voting
# suara : suara
# menempatkan : tempat
# lusail : lusail
# kota : kota
# terbesar : besar
# terletak : letak
# pesisir : pesisir
# selatan : selatan
# provinsi : provinsi
# al : al
# daayen : daayen
# pemerintah : perintah
# merombak : rombak
# dana : dana
# miliar : miliar
# dollar : dollar
# serikat : serikat
# hasil : hasil
# nobatkan : nobat
# pembongkaran : bongkar
# sepak : sepak
# bola : bola
# ras : ras
# abu : abu
# aboud : aboud
# doha : doha
# hebatnya : hebat
# sistem : sistem
# knock : knock
# down : down
# pembangunan : bangun
# tab : tab
# tidur : tidur
# survei : survei
# bbc : bbc
# sport : sport
# memilih : pilih
# gimana : gimana
# kawan : kawan
# setuju : tuju
# thinkfast : thinkfast
# stadium : stadium
# melabuhkan : labuh
# tirainya : tirai
# disebalik : balik
# kehangatan : hangat
# perlawanan : lawan
# dipertandingkan : tanding
# keunikan : uni
# acara : acara
# yuk : yuk
# euforianya : euforia
# berasa : asa
# dipilih : pilih
# pengguna : guna
# internet : internet
# jepun : jepun
# korea : korea
# brazil : brazil
# jerman : jerman
# rusia : rusia
# afrika : afrika
# keberhasilan : hasil
# menyelenggarakan : selenggara
# mengubah : ubah
# imaji : imaji
# global : global
# cenderung : cenderung
# negatif : negatif
# masyarakat : masyarakat
# arab : arab
# nice : nice
# anakku : anak
# suruh : suruh
# skripsi : skripsi
# dampak : dampak
# cebok : cebok
# jadikan : jadi
# jadwal : jadwal
# pertandingan : tanding
# tgl : tgl
# informasi : informasi
# menghubungi : hubung
# wa : wa
# online : online
# mengenang : kenang
# gegap : gegap
# gempita : gempita
# bighit : bighit
# fokusnyah : fokusnyah
# presiden : presiden
# turki : turki
# recep : recep
# tayyip : tayyip
# erdo : erdo
# an : an
# komentari : komentar
# kiprah : kiprah
# cristiano : cristiano
# menurutnya : turut
# dicadangkan : cadang
# alasan : alas
# politik : politik
# marak : marak
# dukungan : dukung
# palestina : palestina
# membela : bela
# jungkook : jungkook
# dreamers : dreamers
# music : music
# from : from
# the : the
# official : official
# soundtrack : soundtrack
# urutan : urut
# lagunya : lagu
# jk : jk
# iyupss : iyupss
# bts : bts
# mencetak : cetak
# lagu : lagu
# tema : tema
# berjudul : judul
# jepang : jepang
# brasil : brasil
# check : check
# out : out
# topi : topi
# logo : logo
# nyama : nyama
# diskon : diskon
# rupiah : rupiah
# dapatkan : dapat
# lazada : lazada
# cod : cod
# terbaru : baru
# puti : puti
# mencatatkan : catat
# rekor : rekor
# pribadi : pribadi
# menyusul : susul
# kemenangan : menang
# capaian : capai
# hingar : hingar
# bingar : bingar
# pesta : pesta
# olahraga : olahraga
# skala : skala
# rampung : rampung
# dilaksanakan : laksana
# manchester : manchester
# united : united
# live : live
# sctv : sctv
# wajib : wajib
# poin : poin
# dialihfungsikan : dialihfungsikan
# dibongkar : bongkar
# rekomendasi : rekomendasi
# situs : situs
# aplikasi : aplikasi
# livescore : livescore
# menyukai : suka
# salah : salah
# populer : populer
# terbukti : bukti
# digelar : gelar
# disaksikan : saksi
# jutaan : juta
# penonton : tonton
# menirukan : tiru
# selebrasi : selebrasi
# hakimi : hakim
# gemerlap : gemerlap
# aksi : aksi
# bintang : bintang
# sepakbola : sepakbola
# memanjakan : manja
# mata : mata
# pecintanya : cinta
# penjuru : penjuru
# ragu : ragu
# menggelontorkan : gelontor
# ribuan : ribu
# triliun : triliun
# terlaksananya : laksana
# sarjana : sarjana
# ugm : ugm
# asli : asli
# anak : anak
# indramayu : indramayu
# dipercaya : percaya
# urus : urus
# keindahan : indah
# baca : baca
# selengkapnya : lengkap
# share : share
# download : download
# rcti : rcti
# berita : berita
# terlengkap : lengkap
# hakim : hakim
# ziyech : ziyech
# memiliki : milik
# kisah : kisah
# menarik : tarik
# membantu : bantu
# maroko : maroko
# semifinal : semifinal
# alexis : alexis
# mac : mac
# allister : allister
# keturunan : turun
# irlandia : irlandia
# media : media
# penggemar : gemar
# menikmati : nikmat
# mencakup : cakup
# persen : persen
# populasi : populasi
# tenggara : tenggara
# pasar : pasar
# negara : negara
# gokils : gokils
# mod : mod
# android : android
# offline : offline
# grafik : grafik
# hd : hd
# new : new
# kits : kits
# squad : squad
# emas : emas
# sepatu : sepatu
# perancis : perancis
# mengalahkan : kalah
# drama : drama
# adu : adu
# udh : udh
# habis : habis
# juarai : juara
# detik : detik
# setinggan : setinggan
# diulang : ulang
# hadeeeeh : hadeeeeh
# yaudah : yaudah
# udah : udah
# tinggal : tinggal
# tunggu : tunggu
# nnti : nnti
# emiliano : emiliano
# martinez : martinez
# perbincangan : bincang
# menjuarai : juara
# melengkapi : lengkap
# trofi : trofi
# dimenangkan : menang
# perjalanan : jalan
# kariernya : karier
# partai : partai
# final : final
# taruhan : taruh
# terpercaya : percaya
# pola : pola
# depositdana : depositdana
# slot : slot
# slotdana : slotdana
# esra : esra
# selvia : selvia
# alumni : alumni
# tel : tel
# perwakilan : wakil
# tampil : tampil
# opening : opening
# closing : closing
# ceremony : ceremony
# nottingham : nottingham
# forest : forest
# liverpool : liverpool
# langkah : langkah
# cepat : cepat
# belanda : belanda
# cody : cody
# gakpo : gakpo
# bermain : main
# solid : solid
# chelsea : chelsea
# perburuan : buru
# pekan : pekan
# dimainkan : main
# minggu : minggu
# kampiun : kampiun
# penalti : penalti
# menikung : tikung
# moncer : moncer
# selangkah : selang
# gabung : gabung
# reds : reds
# resmi : resmi
# psv : psv
# eindhoven : eindhoven
# bersinar : sinar
# unjuk : unjuk
# gigi : gigi
# premier : premier
# league : league
# ff : ff
# de : de
# c : c
# semi : semi
# coba : coba
# cek : cek
# deh : deh
# twibbonize : twibbonize
# part : part
# sikat : sikat
# aston : aston
# villa : villa
# pembuka : buka
# lanjutan : lanjut
# liga : liga
# inggris : inggris
# rto : rto
# agen : agen
# betting : betting
# provider : provider
# dp : dp
# tan : tan
# a : a
# mainkan : main
# geme : geme
# daftar : daftar
# info : info
# penampilan : tampil
# mario : mario
# aji : aji
# paruh : paruh
# musim : musim
# moto : moto
# sportalavista : sportalavista
# satunya : satu
# pembalap : balap
# muda : muda
# kesempatan : sempat
# ajang : ajang
# balap : balap
# motor : motor
# indo : indo
# matchday : matchday
# selasa : selasa
# rabu : rabu
# wib : wib
# kitasatu : kitasatu
# memuat : muat
# disiarkan : siar
# kali : kali
# mengadakan : ada
# polling : polling
# hasilnya : hasil
# netizen : netizen
# kebijakan : bijak
# sesuai : sesuai
# ideologi : ideologi
# negaranya : negara
# lengkap : lengkap
# terburuk : buruk
# simak : simak
# infografis : infografis
# kerasa : rasa
# momen : momen
# gua : gua
# inget : inget
# kayak : kayak
# lupain : lupain
# tahum : tahum
# bicara : bicara
# jagonya : jago
# meraih : raih
# koneksi : koneksi
# kalah : kalah
# telak : telak
# v : v
# janelt : janelt
# brentford : brentford
# jeda : jeda
# pengalaman : alam
# unik : unik
# underrated : underrated
# masya : masya
# allah : allah
# mantan : mantan
# atheis : atheis
# islam : islam
# inggeris : inggeris
# epl : epl
# pura : pura
# lupa : lupa
# arsenal : arsenal
# persada : persada
# tite : tite
# dikabarkan : kabar
# rampok : rampok
# jalan : jalan
# membawa : bawa
# lolos : lolos
# bergulir : gulir
# boxing : boxing
# day : day
# tradisi : tradisi
# bertanding : tanding
# libur : libur
# natal : natal
# krusial : krusial
# persembahan : sembah
# menakjubkan : takjub
# maghribi : maghribi
# pentas : pentas
# inspirasi : inspirasi
# haq : haq
# umur : umur
# bugar : bugar
# mengejar : kejar
# podcast : podcast
# stroberi : stroberi
# wasit : wasit
# akui : aku
# rugikan : rugi
# untungkan : untung
# video : video
# toni : ton
# kroos : kroos
# menyebut : sebut
# terkesan : kes
# performa : performa
# mix : mix
# parlay : parlay
# klik : klik
# dibantu : bantu
# dukun : dukun
# liputan : liput
# menyumbangkan : sumbang
# bus : bus
# lebanon : lebanon
# conte : conte
# protes : protes
# terlupakan : lupa
# aguero : aguero
# terdaftar : daftar
# asisten : asisten
# pelatih : latih
# medali : medali
# berhak : hak
# merayakannya : raya
# diceritakan : cerita
# so : so
# take : take
# note : note
# guys : guys
# terhormat : hormat
# merasakan : rasa
# budaya : budaya
# dipakaikan : pakai
# jubah : jubah
# bisht : bisht
# melepasnya : lepas
# penawarannya : tawar
# selamat : selamat
# pemenang : menang
# event : event
# klaim : klaim
# silahkan : silah
# hubungi : hubung
# tim : tim
# marketing : marketing
# hebat : hebat
# banget : banget
# versi : versi
# animenya : animenya
# keren : keren
# penasaran : penasaran
# langsung : langsung
# var : var
# membalas : balas
# kritikan : kritik
# fans : fans
# mepet : mepet
# persiapan : siap
# pemulihan : pulih
# cape : cape
# salto : salto
# richarlison : richarlison
# gawang : gawang
# serbia : serbia
# turnamen : turnamen
# sepakat : sepakat
# pemilihan : pilih
# phoenix : phoenix
# ngapain : ngapain
# stats : stats
# trophies : trophies
# ama : ama
# setim : tim
# psg : psg
# bawa : bawa
# pildun : pildun
# senior : senior
# dibandingin : dibandingin
# sesat : sesat
# namanya : nama
# wkkw : wkkw
# manajer : manajer
# tottenham : tottenham
# antonio : antonio
# senang : senang
# delapan : delapan
# problemnya : problem
# perkarakan : perkara
# dunianya : dunia
# permusim : musim
# dasarnya : dasar
# status : status
# head : head
# to : to
# id : id
# ditentukan : tentu
# panitia : panitia
# bubar : bubar
# akun : akun
# berkoar : koar
# menumbangkan : tumbang
# dkk : dkk
# babak : babak
# perempat : empat
# lucu : lucu
# selesai : selesai
# sedih : sedih
# tontonan : tonton
# catat : catat
# senin : senin
# jumat : jumat
# januari : januari
# non : non
# stop : stop
# menyajikan : saji
# moji : moji
# tv : tv
# vidio : vidio
# gapai : gapai
# diplomasi : diplomasi
# mundur : mundur
# bidik : bidik
# jose : jose
# mourinho : mourinho
# west : west
# ham : ham
# merayakan : raya
# keragaman : ragam
# toleransi : toleransi
# koeksistensi : koeksistensi
# damai : damai
# gelar : gelar
# individu : individu
# mpv : mpv
# buktinya : bukti
# copa : copa
# finalissima : finalissima
# fwc : fwc
# debatin : debatin
# njing : njing
# skill : skill
# beautiful : beautiful
# dribbling : dribbling
# skills : skills
# goals : goals
# assists : assists
# neymar : neymar
# full : full
# terungkap : ungkap
# szymon : szymon
# marciniak : marciniak
# mengakui : aku
# lakukan : laku
# memimpin : pimpin
# sadar : sadar
# calum : calum
# chambers : chambers
# england : england
# wanita : wanita
# bertekad : tekad
# topless : topless
# istirahatkan : istirahat
# pembukaan : buka
# megah : megah
# penutupan : tutup
# meriah : riah
# manis : manis
# penantian : nanti
# pertamanya : pertama
# akbar : akbar
# tahunan : tahun
# negeri : negeri
# jazirah : jazirah
# sumber : sumber
# terbatas : batas
# menyulap : sulap
# gurun : gurun
# pasir : pasir
# tandus : tandus
# membanggakan : bangga
# dominasi : dominasi
# wags : wags
# dipatahkan : patah
# emak : emak
# pialadunia : pialadunia
# smtm : smtm
# rating : rating
# terendah : rendah
# show : show
# me : me
# money : money
# rendah : rendah
# season : season
# dipengaruhi : pengaruh
# tayang : tayang
# berbarengan : bareng
# sejajar : sejajar
# pele : pele
# maradona : maradona
# strategi : strategi
# mengenalkan : kenal
# ajaran : ajar
# dipecahkan : pecah
# andr : andr
# s : s
# ladies : ladies
# and : and
# gentlemen : gentlemen
# menonton : tonton
# tayangan : tayang
# konten : konten
# livestreaming : livestreaming
# highlight : highlight
# siaran : siar
# ulang : ulang
# seminggu : minggu
# terima : terima
# kasih : kasih
# perform : perform
# menang : menang
# dah : dah
# kangen : kangen
# legenda : legenda
# permalukan : malu
# ngebuktiin : ngebuktiin
# debat : debat
# terjawab : jawab
# blm : blm
# nasib : nasib
# pekerja : kerja
# migran : migran
# pembangun : bangun
# fasilitas : fasilitas
# meninggal : tinggal
# mencapai : capai
# normal : normal
# jumpa : jumpa
# follow : follow
# instagram : instagram
# facebook : facebook
# ekingsnews : ekingsnews
# duel : duel
# dinilai : nilai
# pengusaha : usaha
# nasional : nasional
# boy : boy
# thohir : thohir
# menyaksikan : saksi
# liberia : liberia
# george : george
# weah : weah
# ngantor : ngantor
# alasannya : alas
# kunker : kunker
# kepergok : pergok
# anaknya : anak
# as : as
# kerap : kerap
# menyertakan : serta
# enner : enner
# valencia : valencia
# cetak : cetak
# ekuador : ekuador
# euro : euro
# knp : knp
# penyalamatan : penyalamatan
# kevin : kevin
# marcus : marcus
# bwf : bwf
# championship : championship
# pasangan : pasang
# ganda : ganda
# putra : putra
# andalan : andal
# sanjaya : sanjaya
# gideon : gideon
# menyelesaikan : selesai
# round : round
# esai : esai
# opiniku : opini
# sila : sila
# desi : desi
# rame : rame
# suasana : suasana
# sungguh : sungguh
# ajaib : ajaib
# waras : waras
# kaum : kaum
# kafir : kafir
# miras : miras
# mmng : mmng
# asik : asik
# mnyenangkan : mnyenangkan
# nyaman : nyaman
# aman : aman
# seru : seru
# jalanan : jalan
# ricuh : ricuh
# akrobatik : akrobatik
# nigeria : nigeria
# kumpulan : kumpul
# saudi : saudi
# mexico : mexico
# australia : australia
# pusingan : pusing
# yb : yb
# hee : hee
# loy : loy
# sian : sian
# disember : sember
# ahad : ahad
# kajang : kajang
# menganjurkan : anjur
# sempena : sempena
# pagi : pagi
# petang : petang
# merendahkan : rendah
# selbrasi : selbrasi
# karna : karna
# golden : golden
# glove : glove
# dapan : dap
# ter : ter
# menulis : tulis
# opini : opini
# perihal : perihal
# istimewa : istimewa
# thread : thread
# geliat : geliat
# medioker : medioker
# kembalinya : kembali
# dijuarai : juara
# favorit : favorit
# penuh : penuh
# kejutan : kejut
# via : via
# gelandang : gelandang
# tertawa : tertawa
# geli : geli
# potret : potret
# couple : couple
# iri : iri
# fakta : fakta
# musuh : musuh
# teman : teman
# kesunyian : sunyi
# sergio : sergio
# meresap : resap
# aura : aura
# baharu : baharu
# terinspirasi : inspirasi
# euforia : euforia
# diadain : diadain
# nafa : nafa
# ningkatin : ningkatin
# kesadaran : sadar
# polusi : polusi
# udara : udara
# nafas : nafas
# ngajak : ngajak
# lihat : lihat
# didier : didier
# deschamps : deschamps
# puas : puas
# olivier : olivier
# giroud : giroud
# jam : jam
# bareng : bareng
# sorotan : sorot
# bersejarah : sejarah
# pioneer : pioneer
# terdepannya : depan
# dipercya : dipercya
# kunci : kunci
# team : team
# mbc : mbc
# kehebatan : hebat
# panggung : panggung
# upacara : upacara
# tertarik : tarik
# idola : idola
# laki : laki
# update : update
# ashoy : ashoy
# jasa : jasa
# aged : aged
# domain : domain
# sunatullah : sunatullah
# perubahan : ubah
# menggapai : gapai
# leeds : leeds
# city : city
# ivana : ivana
# knoll : knoll
# mencuri : curi
# perhatian : perhati
# kehadirannya : hadir
# membuatnya : buat
# menangis : menang
# goat : goat
# pecah : pecah
# scaloni : scaloni
# la : la
# albiceleste : albiceleste
# julukan : juluk
# mengangkat : angkat
# ketiga : tiga
# kalinya : kali
# brighton : brighton
# harry : harry
# kane : kane
# skuat : skuat
# point : point
# berlanjut : lanjut
# alhasil : alhasil
# white : white
# sepakan : pakan
# gunting : gunting
# menentang : tentang
# tempoh : tempoh
# kejohanan : johan
# bantahan : bantah
# ribu : ribu
# tanda : tanda
# tangani : tangan
# petisi : petisi
# surabaya : surabaya
# membabat : babat
# ganteng : ganteng
# pls : pls
# tell : tell
# rodrigo : rodrigo
# paul : paul
# alisson : alisson
# trapp : trapp
# bremer : bremer
# dikalahkan : kalah
# belajar : ajar
# menghilangkan : hilang
# pikiran : pikir
# tentangnya : tentang
# nicolas : nicolas
# jaeger : jaeger
# ateis : ateis
# perhelatan : helat
# menteri : menteri
# usaha : usaha
# milik : milik
# bumn : bumn
# erick : erick
# kagum : kagum
# penyelenggaraan : selenggara
# menilai : nilai
# transformasi : transformasi
# pesat : pesat
# tinggalkan : tinggal
# vamos : vamos
# impian : impi
# pengen : ken
# aamiiiiin : aamiiiiin
# ahli : ahli
# parlimen : parlimen
# oman : om
# menawarkan : tawar
# juta : juta
# rm : rm
# dipakainya : pakai
# selepas : lepas
# muncul : muncul
# saingan : saing
# disambung : sambung
# isnin : isnin
# sebulan : bulan
# terhenti : henti
# laluan : lalu
# temasya : temasya
# kiper : kiper
# inter : inter
# andre : andre
# onana : onana
# pensiun : pensiun
# kamerun : kamerun
# bertengkar : tengkar
# rigobert : rigobert
# song : song
# rezeki : rezeki
# diraup : raup
# harta : harta
# pendapatan : dapat
# diperolehnya : oleh
# berpunya : punya
# turun : turun
# terakhirnya : akhir
# ale : ale
# kelimanya : lima
# menyamai : sama
# prestasinya : prestasi
# klub : klub
# berlogo : logo
# burung : burung
# camar : camar
# terpaut : paut
# topskor : topskor
# leandro : leandro
# trossard : trossard
# neal : neal
# maupay : maupay
# kbri : kbri
# menggelar : gelar
# malam : malam
# apresiasi : apresiasi
# sukarelawan : sukarelawan
# terlibat : libat
# buntut : buntut
# brutal : brutal
# uruguay : uruguay
# terancam : ancam
# sanksi : sanksi
# jatuh : jatuh
# bicycle : bicycle
# kick : kick
# melumat : lumat
# grup : grup
# g : g
# restoran : restoran
# cabang : cabang
# asalnya : asal
# restorannya : restoran
# uk : uk
# senarai : senarai
# hadiah : hadiah
# wang : wang
# tunai : tunai
# penghargaan : harga
# sanggar : sanggar
# seni : seni
# tokoh : tokoh
# aktif : aktif
# mempromosikan : promosi
# eropa : eropa
# munafik : munafik
# trailer : trailer
# kocak : kocak
# feat : feat
# coach : coach
# justin : justin
# bocil : bocil
# senggo : senggo
# bri : bri
# persikabo : persikabo
# persib : persib
# bandung : bandung
# persebaya : baya
# sabtu : sabtu
# total : total
# peserta : serta
# penyelenggara : selenggara
# iconic : iconic
# seri : seri
# x : x
# menit : menit
# ft : ft
# kamboja : kamboja
# mengawali : awal
# gacorjam : gacorjam
# respect : respect
# usia : usia
# skor : skor
# hattick : hattick
# pengunjung : unjung
# memeluk : peluk
# agama : agama
# muallaf : muallaf
# maklumat : maklumat
# pembicaraan : bicara
# prestasi : prestasi
# menggeser : geser
# pemegang : pegang
# like : like
# ig : ig
# kes : kes
# minum : minum
# air : air
# banjir : banjir
# is : is
# best : best
# ever : ever
# kupasan : kupas
# edisi : edisi
# move : move
# on : on
# berat : berat
# nama : nama
# cucunya : cucu
# muhammad : muhammad
# keseruan : seru
# skenario : skenario
# memenangkan : menang
# kroasia : kroasia
# andai : andai
# jejak : jejak
# kentut : kentut
# bosquh : bosquh
# kompetisi : kompetisi
# cosplayernya : cosplayernya
# twitter : twitter
# vkryp : vkryp
# anime : anime
# corner : corner
# eloklah : elok
# siasat : siasat
# tindakan : tindak
# salt : salt
# bae : bae
# mengganggu : ganggu
# dimenangi : tang
# mengundang : undang
# kemarahan : marah
# warganet : warganet
# yahh : yahh
# setara : tara
# ambek : ambek
# iran : iran
# kualifikasi : kualifikasi
# oh : oh
# see : see
# hahahahahahhaha : hahahahahahhaha
# henti : henti
# dilangsungkan : langsung
# kabar : kabar
# telanjang : telanjang
# dada : dada
# dipenjara : penjara
# lifestyle : lifestyle
# fan : fan
# token : token
# chef : chef
# sok : sok
# asyik : asyik
# foto : foto
# pegang : pegang
# cium : cium
# lapangan : lapang
# juaranya : juara
# menyita : sita
# ambil : ambil
# postingan : postingan
# membakar : bakar
# amarah : amarah
# setia : setia
# crsitiano : crsitiano
# sudut : sudut
# pandang : pandang
# otw : otw
# sabet : sabet
# ballon : ballon
# or : or
# fatsoen : fatsoen
# terkenal : kenal
# xi : xi
# dilansir : lansir
# ngga : ngga
# komen : komen
# pilihan : pilih
# dibawah : bawah
# kopi : kopi
# senja : senja
# capek : capek
# lapangin : lapangin
# seluas : luas
# kemaren : kemaren
# kehilangan : hilang
# gabriel : gabriel
# jesus : jesus
# lutut : lutut
# alami : alami
# polis : polis
# menumpaskan : tumpas
# kegiatan : giat
# perjudian : judi
# penahanan : tahan
# bookie : bookie
# punter : punter
# serbuan : serbu
# november : november
# kelmarin : kelmarin
# lgbt : lgbt
# tu : tu
# sah : sah
# penyumbang : sumbang
# penyakit : sakit
# aids : aids
# hiv : hiv
# org : org
# diseluruh : seluruh
# elok : elok
# pulak : pulak
# bg : bg
# sokongan : sokong
# smp : smp
# beria : ria
# konon : konon
# golongan : golong
# songsang : songsang
# menghalang : halang
# bentuk : bentuk
# dipiala : piala
# baee : baee
# juru : juru
# masak : masak
# gizi : gizi
# ranking : ranking
# teratas : atas
# chat : chat
# whatsapp : whatsapp
# dikirim : kirim
# i : i
# spanyol : spanyol
# mari : mari
# flashback : flashback
# moment : moment
# sambutannya : sambut
# pemikiran : pikir
# perempuan : perempuan
# berbuat : buat
# spt : spt
# mencontohkan : contoh
# davies : davies
# kanada : kanada
# menjaringkan : jaring
# diraja : diraja
# malaysia : malaysia
# pdrm : pdrm
# berjaya : jaya
# menahan : tahan
# disyaki : syak
# pertaruhan : taruh
# ramai : ramai
# memegang : pegang
# mencium : cium
# membuka : buka
# penyelidikan : lidi
# bernama : nama
# nusret : nusret
# gokce : gokce
# ikutan : ikut
# menyambut : sambut
# utara : utara
# ketahui : tahu
# penyerang : serang
# bolavita : bolavita
# mnc : mnc
# sbobet : sbobet
# bank : bank
# buka : buka
# perilaku : perilaku
# undangan : undang
# melawan : lawan
# replika : replika
# dipasangkan : pasang
# emir : emir
# menerusi : terusi
# tahan : tahan
# bukit : bukit
# kertas : kertas
# siasatan : siasat
# berkait : kait
# tahukah : tahu
# byk : byk
# darah : darah
# keringat : keringat
# tumbal : tumbal
# infrastruktur : infrastruktur
# bayangkan : bayang
# wajah : wajah
# des : des
# berbareng : bareng
# internasional : internasional
# gianni : gianni
# infantino : infantino
# kepala : kepala
# kenangan : kenang
# alkubaisi : alkubaisi
# real : real
# madrid : madrid
# mempertimbangkan : timbang
# bek : bek
# berbakat : bakat
# leipzig : leipzig
# josko : josko
# gvardiol : gvardiol
# berusia : usia
# mengesankan : kesan
# finis : finis
# ambassador : ambassador
# aice : aice
# raih : raih
# th : th
# anniv : anniv
# polandia : polandia
# memecat : pecat
# czeslaw : czeslaw
# michniewicz : michniewicz
# mengantarkan : antar
# robert : robert
# lewandoswki : lewandoswki
# dihentikan : henti
# ane : ane
# berkesan : kesan
# you : you
# target : target
# istri : istri
# wkwk : wkwk
# parade : parade
# adakah : ada
# main : main
# eks : eks
# striker : striker
# italia : italia
# emosi : emosi
# kelakuan : laku
# bro : bro
# eddas : eddas
# isinya : isi
# likenya : likenya
# pantesan : pantesan
# mecahin : mecahin
# likes : likes
# ligue : ligue
# berkat : berkat
# apiknya : apik
# souq : souq
# waqif : waqif
# permintaan : minta
# melonjak : lonjak
# membeli : beli
# memakainya : maka
# tamim : tamim
# bin : bin
# hamad : hamad
# thani : thani
# minim : minim
# lombok : lombok
# insider : insider
# menyisakan : sisa
# kesan : kesan
# sejagat : jagat
# raya : raya
# semoga : moga
# secepatnya : cepat
# marroqiuno : marroqiuno
# khayalak : khayalak
# bumi : bumi
# champion : champion
# bpp : bpp
# termahal : mahal
# dikenakan : kena
# kontroversi : kontroversi
# terpantau : pantau
# peningkatan : tingkat
# japan : japan
# posisi : posisi
# road : road
# wr : wr
# mak : mak
# nyak : nyak
# doel : doel
# sekolahan : sekolah
# ajar : ajar
# miko : miko
# ibumu : ibu
# ngerti : ngerti
# split : split
# hidung : hidung
# alfatihah : alfatihah
# seishun : seishun
# girl : girl
# antonella : antonella
# roccuzzo : roccuzzo
# hadir : hadir
# mendukung : dukung
# sang : sang
# suami : suami
# mengajak : ajak
# kecilnya : kecil
# ayah : ayah
# kompak : kompak
# ber : ber
# jersey : jersey
# nomor : nomor
# punggung : punggung
# dodo : dodo
# hoax : hoax
# menghormati : hormat
# chuakzz : chuakzz
# format : format
# komersialisasi : komersialisasi
# permainan : main
# mencoba : coba
# memeras : peras
# lemon : lemon
# dipeluk : peluk
# misterius : misterius
# kegirangan : girang
# sosok : sosok
# christiano : christiano
# pindah : pindah
# dikontrak : kontrak
# club : club
# nassr : nassr
# sekakigus : sekakigus
# brand : brand
# ambasador : ambasador
# kesehariannya : hari
# enam : enam
# rising : rising
# star : star
# digadang : gadang
# gadang : gadang
# menggantikan : ganti
# jago : jago
# supepippo : supepippo
# tersendiri : sendiri
# dngn : dngn
# cadangan : cadang
# dr : dr
# cr : cr
# hmm : hmm
# do : do
# more : more
# research : research
# menaklukkan : takluk
# kejuaraan : juara
# kerja : kerja
# keras : keras
# statistik : statistik
# pertimbangan : timbang
# ikon : ikon
# uang : uang
# peso : peso
# pulga : pulga
# lepas : lepas
# peran : peran
# induk : induk
# merilis : rilis
# rangking : rangking
# terbarunya : baru
# kamis : kamis
# tepatnya : tepat
# warga : warga
# menyembut : menyembut
# kedatangan : datang
# daerah : daerah
# berjuluk : juluk
# tanggo : tanggo
# banteng : banteng
# sumut : sumut
# nobar : nobar
# dimeriahkan : riah
# stand : stand
# up : up
# comedy : comedy
# games : games
# quiz : quiz
# pengamen : amen
# ketua : ketua
# dpd : dpd
# bmi : bmi
# franky : franky
# partogi : partogi
# wijaya : wijaya
# sirait : sirait
# pesan : pesan
# beredar : edar
# sekumpulan : kumpul
# serentak : serentak
# membaca : baca
# kalimat : kalimat
# syahadat : syahadat
# diklaim : klaim
# supporter : supporter
# menari : tari
# fase : fase
# gugur : gugur
# mengantisipasi : antisipasi
# wajar : wajar
# ruang : ruang
# berkembang : kembang
# defender : defender
# menonjol : tonjol
# sanggup : sanggup
# nominal : nominal
# lho : lho
# kegemilangan : gemilang
# incaran : incar
# wisatawan : wisatawan
# detikers : detikers
# maaf : maaf
# kompensasi : kompensasi
# pelanggan : langgan
# kenal : kenal
# keponya : keponya
# salam : salam
# untungnya : untung
# trauma : trauma
# terbayar : bayar
# lunass : lunass
# sarawak : sarawak
# menangkap : tangkap
# dipercayai : percaya
# aktiviti : aktiviti
# mengincar : incar
# kursi : kursi
# olimpiade : olimpiade
# korsel : korsel
# afsel : afsel
# latin : latin
# usa : usa
# mks : mks
# knd : knd
# jth : jth
# host : host
# kesayangan : sayang
# agus : agus
# menganalisis : analis
# tonton : tonton
# ulasan : ulas
# lengkapnya : lengkap
# angkat : angkat
# ditawar : tawar
# pengusahan : usah
# f : f
# ac : ac
# dc : dc
# fba : fba
# db : db
# ed : ed
# ba : ba
# bade : bade
# bcc : bcc
# eefdc : eefdc
# pemanis : man
# histroy : histroy
# dihargainya : harga
# peristiwa : peristiwa
# momentum : momentum
# tato : tato
# ronaldinho : ronaldinho
# layak : layak
# mengharukan : haru
# enzo : enzo
# fernandez : fernandez
# idolanya : idola
# mimpi : mimpi
# kenyataan : nyata
# tangga : tangga
# terbaharu : baharu
# persekutuan : sekutu
# persatuan : satu
# antarabangsa : antarabangsa
# sampah : sampah
# berserakan : sera
# menyempurnakan : sempurna
# pesepak : sepak
# profesional : profesional
# semifinalis : semifinalis
# kesel : kesel
# heboh : heboh
# terpampang : pampang
# sulit : sulit
# sibuk : sibuk
# berdebat : debat
# bertemu : temu
# dzakir : dzakir
# da : da
# khabib : khabib
# nurmagomedov : nurmagomedov
# kelas : kelas
# ringan : ringan
# ufc : ufc
# rangka : rangka
# ceramah : ceramah
# larang : larang
# pakai : pakai
# iniesta : iniesta
# sejati : sejati
# kecuali : kecuali
# suka : suka
# patut : patut
# pujian : puji
# namum : namum
# assist : assist
# deretan : deret
# diabadikan : abadi
# ngalahin : ngalahin
# pahlawan : pahlawan
# judi : judi
# xwin : xwin
# winrate : winrate
# pelayanan : layan
# tercepat : cepat
# withdraw : withdraw
# buruan : buru
# join : join
# hub : hub
# pagelaran : pagelaran
# platform : platform
# menyuarakan : suara
# komunikasi : komunikasi
# pendapatmu : dapat
# gacor : gacor
# anti : anti
# bocor : bocor
# ditto : ditto
# hug : hug
# siang : siang
# fajri : fajri
# op : op
# soga : soga
# nestapa : nestapa
# tersaji : saji
# kedau : kedau
# optimis : optimis
# menangais : menangais
# kekalahan : kalah
# tersungkur : sungkur
# putaran : putar
# diikuti : ikut
# pria : pria
# anggota : anggota
# news : news
# gila : gila
# berpesta : pesta
# memecahkan : pecah
# telur : telur
# viral : viral
# memanggil : panggil
# sebutan : sebut
# keluarga : keluarga
# berperan : peran
# vital : vital
# layaknya : layak
# bernomor : nomor
# sbg : sbg
# fantastis : fantastis
# usd : usd
# wow : wow
# rincian : rincian
# melansir : lansir
# national : national
# diperoleh : oleh
# pamer : pamer
# segini : gin
# istirahat : istirahat
# berlatih : latih
# paris : paris
# saint : saint
# germain : germain
# devina : devina
# nasi : nasi
# gorengnya : goreng
# icon : icon
# fair : fair
# play : play
# mempersembahkan : sembah
# shirt : shirt
# cotton : cotton
# combat : combat
# sablon : sablon
# plastisol : plastisol
# harga : harga
# po : po
# spain : spain
# enterslots : enterslots
# ramaikan : ramai
# fraksi : fraksi
# pks : pks
# depok : depok
# qurtifa : qurtifa
# futsal : futsal
# penggawa : penggawa
# ibunya : ibu
# menemui : temu
# raja : raja
# gaes : gaes
# kesedihan : sedih
# rindu : rindu
# kemeriahan : riah
# man : man
# utd : utd
# kitman : kitman
# all : all
# time : time
# epik : epik
# legend : legend
# sayang : sayang
# dilewatkan : lewat
# kemang : kemang
# jakarta : jakarta
# good : good
# dukungannya : dukung
# sektor : sektor
# persampahan : sampah
# mendaur : daur
# bully : bully
# bilangan : bilang
# settingan : settingan
# nangis : nang
# kepanasan : panas
# meledak : ledak
# ledak : ledak
# rashford : rashford
# eksplosifnya : eksplosif
# mu : mu
# giovanni : giovanni
# vincenzo : vincenzo
# administrator : administrator
# membagikan : bagi
# favoritnya : favorit
# perusahaan : usaha
# china : china
# mendominasi : dominasi
# sponsor : sponsor
# kakak : kakak
# google : google
# search : search
# pep : pep
# guardiola : guardiola
# dijajaran : jajar
# staf : staf
# pablo : pablo
# aimar : aimar
# roberto : roberto
# ayala : ayala
# walter : walter
# samuel : samuel
# kieran : kieran
# trippier : trippier
# keputusan : putus
# bertahan : tahan
# gareth : gareth
# southgate : southgate
# arsitek : arsitek
# zinedine : zinedine
# zidane : zidane
# latih : latih
# karim : karim
# batal : batal
# mengagumkan : kagum
# open : open
# order : order
# kaos : kaos
# stok : stok
# east : east
# nusa : nusa
# janji : janji
# berdasarkan : dasar
# gambar : gambar
# diatas : atas
# pendukung : dukung
# rollercoaster : rollercoaster
# aturan : atur
# sugbk : sugbk
# seketat : ketat
# menabjukan : menabjukan
# mengejutkan : kejut
# diqatar : diqatar
# peraih : raih
# sarung : sarung
# tangan : tangan
# piers : piers
# morgan : morgan
# sombong : sombong
# ridwan : ridwan
# kamil : kamil
# disapa : sapa
# kang : kang
# emil : emil
# meramal : ramal
# kontribusi : kontribusi
# kakaknya : kakak
# kecewa : kecewa
# reels : reels
# emang : emang
# vibes : vibes
# graham : graham
# arnold : arnold
# l : l
# equipe : equipe
# bercerita : cerita
# pribadinya : pribadi
# tempuh : tempuh
# mewujudkan : wujud
# mimpinya : mimpi
# drake : drake
# senilai : nila
# miliarnya : miliar
# kesenangan : senang
# tumpah : tumpah
# berukuran : ukur
# raksasa : raksasa
# grafiti : grafit
# usil : usil
# mengganti : ganti
# buenos : buenos
# aires : aires
# petualangan : tualang
# menyedihkan : sedih
# bergabung : gabung
# starting : starting
# lautaro : lautaro
# syeikh : syeikh
# quran : quran
# dibacakan : baca
# konsultasikan : konsultasi
# kebutuhan : butuh
# solarkita : solarkita
# plts : plts
# pemasok : pasok
# energi : energi
# konfederasi : konfederasi
# conmebol : conmebol
# menghadiahkan : hadiah
# dolar : dolar
# pdip : pdip
# perdebatan : debat
# mengemban : emban
# titel : titel
# no : no
# tulis : tulis
# terhebat : hebat
# spasogoal : spasogoal
# swedia : swedia
# penambahan : tambah
# dongeng : dongeng
# suporter : suporter
# kampung : kampung
# sambut : sambut
# undang : undang
# istana : istana
# mohammed : mohammed
# vi : vi
# skuad : skuad
# perwira : perwira
# gemilang : gemilang
# petarung : tarung
# diego : ego
# cs : cs
# dievakuasi : evakuasi
# helikopter : helikopter
# bayi : bayi
# rayyanza : rayyanza
# cipung : cipung
# yuhuuu : yuhuuu
# dicintai : cinta
# nora : nora
# fatehi : fatehi
# penyanyi : nyanyi
# berkutik : kutik
# penerus : terus
# jagoanmu : jago
# ditemani : tani
# bobok : bobok
# tergilicir : tergilicir
# bumbung : bumbung
# bas : bas
# rai : rai
# sikit : sikit
# nak : nak
# cacat : cacat
# terhumban : terhumban
# dinaikinya : naik
# sesi : sesi
# perarakan : ara
# meraikan : rai
# kejayaan : jaya
# berulah : ulah
# sasaran : sasar
# duh : duh
# rosario : rosario
# dikepung : kepung
# perang : perang
# ukraina : ukraina
# membuktikan : bukti
# betapa : betapa
# rasis : ras
# arogannya : arogan
# lucunya : lucu
# mengkritik : kritik
# timur : timur
# mengemis : emis
# pasokan : pasok
# minyak : minyak
# gas : gas
# jawara : jawara
# berucap : ucap
# gegara : gegara
# paham : paham
# kawasan : kawasan
# dibanding : banding
# beda : beda
# tango : tango
# menerima : terima
# kakanwil : kakanwil
# faisol : faisol
# ali : ali
# jagokan : jago
# sulbar : sulbar
# artis : artis
# vallen : vallen
# donna : donna
# agnesia : agnesia
# kemenkumham : kemenkumham
# kebersamaan : sama
# koki : koki
# dikecam : kecam
# tropi : tropi
# bolaaceh : bolaaceh
# dituding : tuding
# curang : curang
# boxbola : boxbola
# menghadirkan : hadir
# bertalenta : talenta
# geser : geser
# kafe : kafe
# pesawat : pesawat
# profil : profil
# milan : mil
# lois : lois
# openda : openda
# dibawa : bawa
# tajam : tajam
# usianya : usia
# psywar : psywar
# mampir : mampir
# gara : gara
# lompat : lompat
# jembatan : jembatan
# pecahkan : pecah
# unggahan : unggah
# miliki : milik
# diasian : asi
# bertempat : tempat
# mempesona : pesona
# mustahil : mustahil
# dipertunjukan : tunjuk
# distadion : stadion
# dirumah : rumah
# bosan : bosan
# perjuangan : juang
# merangkul : rangkul
# level : level
# laris : laris
# kerumunan : kerumun
# menggila : gila
# terpaksa : paksa
# diterbangkan : terbang
# mengalungkan : alung
# royal : royal
# wissam : wissam
# mengharumkan : harum
# disambut : sambut
# bak : bak
# kakinya : kaki
# kesuksesan : sukses
# rayakan : raya
# kening : kening
# petugas : tugas
# keamanan : aman
# tuntas : tuntas
# kehidupan : hidup
# lautan : laut
# ratusan : ratus
# bentrok : bentrok
# polisi : polisi
# pusat : pusat
# brussels : brussels
# belgia : belgia
# melambungkan : lambung
# menjalani : jalan
# debutnya : debut
# signifikan : signifikan
# menyisihkan : sisih
# rekan : rekan
# seniornya : senior
# sob : sob
# dicetak : cetak
# harganya : harga
# meroket : roket
# baju : baju
# identitas : identitas
# sosoknya : sosok
# segampang : gampang
# ngebalikin : ngebalikin
# telapak : telapak
# dapet : dapet
# trophy : trophy
# doi : doi
# habiskan : habis
# untung : untung
# locked : locked
# mumpung : mumpung
# theo : theo
# bantuan : bantu
# buzzer : buzzer
# garut : garut
# mengantar : antar
# terkam : terkam
# desa : desa
# maju : maju
# peesesi : peesesi
# mestinya : mesti
# bangga : bangga
# tajir : tajir
# melintir : melintir
# kekayaan : kaya
# english : english
# fa : fa
# wira : wira
# menjejakkan : jejak
# tanahair : tanahair
# penamat : tamat
# keempat : empat
# kempen : kempen
# champhionship : champhionship
# diadakan : ada
# bergengsi : gengsi
# melahirkan : lahir
# rabat : rabat
# ibukota : ibukota
# kepulangan : pulang
# ciptakan : cipta
# burnley : burnley
# carabao : carabao
# kesuksesannya : sukses
# jajaran : jajar
# kepelatihan : latih
# membimbing : bimbing
# melatih : latih
# pegiat : giat
# blog : blog
# analis : analis
# utas : utas
# gantung : gantung
# meme : meme
# menerka : terka
# pelajaran : ajar
# memenangi : tang
# ketujuh : tujuh
# menyorot : sorot
# umpan : umpan
# gue : gue
# wakandasia : wakandasia
# presidennya : presiden
# kacung : kacung
# naga : naga
# kejadian : jadi
# mati : mati
# pengurusnya : urus
# nabur : nabur
# bunga : bunga
# calon : calon
# jebolan : jebol
# ndez : ndez
# jagoan : jago
# mobil : mobil
# toyota : toyota
# jagoannya : jago
# sobat : sobat
# setiajaya : setiajaya
# mesin : mesin
# pencarian : cari
# trafik : trafik
# mencurahkan : curah
# kebahagiannya : kebahagiannya
# tulisan : tulis
# menuliskan : tulis
# perjuangnnya : perjuangnnya
# agun : agun
# gunandjar : gunandjar
# sudarsa : sudarsa
# traveling : traveling
# timnya : tim
# cuitan : cuit
# perjumpaan : jumpa
# kegilaan : gila
# perayaan : raya
# kabur : kabur
# romy : romy
# ury : ury
# rafael : rafael
# tebak : tebak
# ngel : ngel
# maria : maria
# sensasional : sensasional
# tertinggi : tinggi
# laporan : lapor
# nbc : nbc
# us : us
# etimologi : etimologi
# berasal : asal
# irina : irina
# shayk : shayk
# ex : ex
# boyfriend : boyfriend
# penutup : tutup
# era : era
# karier : karier
# rival : rival
# diletakkan : letak
# bangku : bangku
# simpanan : simpan
# tewas : tewas
# mengejut : kejut
# champions : champions
# tekanan : tekan
# kemampuan : mampu
# faktor : faktor
# berubah : ubah
# tragedi : tragedi
# sosial : sosial
# popularitas : popularitas
# cnn : cnn
# memainkan : main
# sisa : sisa
# gmb : gmb
# hidup : hidup
# muslimah : muslimah
# memakaikan : pakai
# muslim : muslim
# hitam : hitam
# khas : khas
# gratis : gratis
# kpd : kpd
# bule : bule
# angel : angel
# penalty : penalty
# has : has
# done : done
# it : it
# in : in
# jokowi : jokowi
# seputar : putar
# score : score
# member : member
# beruntung : untung
# sesungguhnya : sungguh
# fff : fff
# mengutuk : kutuk
# pelecehan : leceh
# rasisme : rasisme
# ucapan : ucap
# bocoran : bocor
# mimin : mimin
# bong : bong
# candra : candra
# apes : apes
# topscore : topscore
# hugo : hugo
# lloris : lloris
# france : france
# dau : dau
# malang : malang
# jawa : jawa
# selesainya : selesai
# diusir : usir
# kartu : kartu
# merah : merah
# pos : pos
# rw : rw
# bsp : bsp
# kalahkan : kalah
# berkebalikan : balik
# memutuskan : putus
# bertarung : tarung
# sheikh : sheikh
# penyerahan : serah
# penjaga : jaga
# shorts : shorts
# erdogan : erdogan
# elon : elon
# musk : musk
# menyindir : sindir
# bermuka : muka
# diajang : ajang
# karma : karma
# tutup : tutup
# mulut : mulut
# gaung : gaung
# data : data
# dikumpulkan : kumpul
# impresi : impresi
# detail : detail
# percakapan : cakap
# wkwkwm : wkwkwm
# berkah : berkah
# pelaku : laku
# umkm : umkm
# gorontalo : gorontalo
# tahniah : tahniah
# bendera : bendera
# menghiasi : hias
# towers : towers
# streaming : streaming
# raffi : raffi
# ahmad : ahmad
# nagita : nagita
# slavina : slavina
# finla : finla
# lokasi : lokasi
# malaikat : malaikat
# ungkit : ungkit
# sekian : sekian
# ngeselin : ngeselin
# katain : katain
# dasar : dasar
# gen : gen
# z : z
# norak : norak
# bahagia : bahagia
# dipulangkan : pulang
# menggemparkan : gempar
# pelosok : pelosok
# terkecuali : kecuali
# kabupaten : kabupaten
# kebumen : kebumen
# berbondong : bondong
# bondong : bondong
# pendopo : pendopo
# kabumian : kabumian
# versus : versus
# ucapkan : ucap
# seronok : seronok
# lipatan : lipat
# sukan : sukan
# winner : winner
# istanbul : istanbul
# cim : cim
# mendunia : dunia
# semalam : malam
# suntuk : suntuk
# senonoh : senonoh
# balas : balas
# cemoohan : cemooh
# scorer : scorer
# kempes : kempes
# mengunggah : unggah
# fotonya : foto
# pemberian : beri
# intip : intip
# penuntasan : tuntas
# dahaga : dahaga
# buah : buah
# taktik : taktik
# sebastian : sebastian
# surya : surya
# diiringi : iring
# one : one
# home : home
# game : game
# argentia : argentia
# mejadi : mejadi
# contoh : contoh
# thn : thn
# melebihi : lebih
# amin : amin
# nekat : nekat
# jalannya : jalan
# co : co
# agent : agent
# web : web
# rslot : rslot
# website : website
# utama : utama
# spesial : spesial
# rtp : rtp
# pragmatic : pragmatic
# cuan : cuan
# win : win
# bosku : bos
# pdrmsia : pdrmsia
# johor : johor
# tumpaskan : tumpas
# pautan : paut
# harian : hari
# pepe : pepe
# sgtoto : sgtoto
# cairkan : cair
# mimpiku : mimpi
# bersamamu : sama
# adidas : adidas
# original : original
# mencotoh : mencotoh
# word : word
# bermimpi : mimpi
# enak : enak
# ditandai : tanda
# sahabat : sahabat
# pedooli : pedooli
# mempertontonkan : tonton
# ideal : ideal
# cinta : cinta
# istrinya : istri
# antonela : antonela
# mendukungnya : dukung
# winslot : winslot
# bangladesh : bangladesh
# ritual : ritual
# keraguan : ragu
# berlaga : laga
# mengenakan : kena
# sepasang : pasang
# boots : boots
# sandal : sandal
# menyentuh : sentuh
# mengemas : emas
# rizal : rizal
# effendi : effendi
# menutup : tutup
# cerita : cerita
# semaraknya : semarak
# kecantikan : cantik
# salman : salman
# pangeran : pangeran
# mbs : mbs
# diperkuat : kuat
# nantikan : nanti
# bayern : bayern
# munchen : munchen
# murka : murka
# kingsley : kingsley
# coman : coman
# rasial : rasial
# america : america
# sakral : sakral
# berfoto : foto
# cucu : cucu
# armando : armando
# benjamin : benjamin
# menetapkan : tetap
# tanggal : tanggal
# deepika : deepika
# padukone : padukone
# menjelang : jelang
# diarak : arak
# keliling : keliling
# nielsen : nielsen
# company : company
# olah : olah
# inews : inews
# pemirsa : pirsa
# program : program
# ditonton : tonton
# formasi : formasi
# reaksi : reaksi
# dibalik : balik
# suksesnya : sukses
# suap : suap
# petinggi : petinggi
# matinya : mati
# membangun : bangun
# gagalnya : gagal
# larangan : larang
# wine : wine
# dll : dll
# pro : pro
# kontra : kontra
# tradisional : tradisional
# dipakai : pakai
# laku : laku
# terjual : jual
# bismillah : bismillah
# intuisi : intuisi
# bohong : bohong
# uji : uji
# akurat : akurat
# menebak : tebak
# gaya : gaya
# menganggapnya : anggap
# canggung : canggung
# tersangkut : sangkut
# kabel : kabel
# melintang : lintang
# keputusannya : putus
# dybala : dybala
# pulih : pulih
# cedera : cedera
# carlo : carlo
# ancelotti : ancelotti
# melanjutkan : lanjut
# pembagian : bagi
# ngenes : ngenes
# pekanbaru : pekanbaru
# mengikuti : ikut
# menghelat : helat
# pelecut : lecut
# senyum : senyum
# menangisi : tangis
# nasibnya : nasib
# peforma : forma
# soccer : soccer
# mania : mania
# seramai : serama
# ditahan : tahan
# ix : ix
# dijalankan : jalan
# nawacita : nawacita
# penerimaan : terima
# wilayah : wilayah
# pelaksanaannya : laksana
# nov : nov
# majalah : majalah
# bisnis : bisnis
# mingguan : minggu
# runner : runner
# soft : soft
# power : power
# teknologi : teknologi
# offside : offside
# otomatis : otomatis
# diperkenalkan : kenal
# seria : ria
# pengakuan : aku
# percaya : percaya
# jimat : jimat
# gelang : gelang
# cristian : cristian
# gonzales : gonzales
# remehkan : remeh
# pegelaran : gelar
# efektif : efektif
# indah : indah
# ditorehkan : toreh
# sepulang : pulang
# tuai : tuai
# kecaman : kecam
# kejalan : jalan
# gampang : gampang
# ditebak : tebak
# pengamat : amat
# nebak : nebak
# paspalum : paspalum
# vaginalum : vaginalum
# pantai : pantai
# rumput : rumput
# jenis : jenis
# tangguh : tangguh
# auto : auto
# rebutan : rebut
# ketar : ketar
# ketir : tir
# pasukan : pasu
# mendarat : darat
# mengharungi : mengharungi
# teroooss : teroooss
# menpora : menpora
# temui : temu
# bahas : bahas
# hujan : hujan
# followers : followers
# kemenanganny : kemenanganny
# fantasy : fantasy
# tata : tata
# klasemen : klasemen
# liganya : liga
# tergerak : gerak
# tandem : tandem
# umumkan : umum
# penyihir : sihir
# rilis : rilis
# pencapaian : capai
# kiprahnya : kiprah
# pemenangnya : menang
# pecinta : cinta
# ishowspeed : ishowspeed
# diantar : antar
# direbut : rebut
# penerima : terima
# pembaruan : baru
# connected : connected
# ball : ball
# kepoin : poin
# kecanggihannya : canggih
# sembari : sembari
# menyongsong : songsong
# lucah : lucah
# pingat : pingat
# sahaja : sahaja
# tumpuan : tumpu
# tangkasnya : tangkas
# lawan : lawan
# keabsahannya : absah
# ikonik : ikonik
# ilmu : ilmu
# pendekatan : dekat
# metode : metode
# normatif : normatif
# perkenalkan : kenal
# gt : gt
# semangat : semangat
# selevel : level
# pemimpin : pimpin
# bandara : bandara
# ministro : ministro
# pistarini : pistarini
# ezeiza : ezeiza
# kehadiran : hadir
# politisi : politis
# golkar : golkar
# dedi : dedi
# mulyadi : mulyadi
# dpr : dpr
# ri : ri
# putri : putri
# indriani : indriani
# bupati : bupati
# luwu : luwu
# ahmed : ahmed
# zaki : zaki
# iskandar : iskandar
# tangerang : tangerang
# mah : mah
# bebas : bebas
# alberto : alberto
# sebagia : sebagia
# hangat : hangat
# saudara : saudara
# berkibar : kibar
# mengibarkan : kibar
# sebelas : sebelas
# gerakan : gera
# cabul : cabul
# tekuk : tekuk
# nilai : nilai
# ringgit : ringgit
# univ : univ
# bedakan : beda
# termegah : megah
# wikipedia : wikipedia
# beserta : serta
# idama : idama
# dimana : mana
# trbaik : trbaik
# hadirkan : hadir
# dakwah : dakwah
# rara : rara
# congratulation : congratulation
# demam : demam
# padat : padat
# merayap : rayap
# keramaian : ramai
# penduduk : duduk
# milyar : milyar
# menggoreskan : gores
# tinta : tinta
# penyambutan : sambut
# mega : mega
# hijau : hijau
# seremoni : seremoni
# yess : yess
# topik : topik
# ditulis : tulis
# ancang : ancang
# nulis : nulis
# ciamik : ciamik
# perpanjang : panjang
# kontrak : kontrak
# lionle : lionle
# posting : posting
# atlet : atlet
# disukai : suka
# javier : javier
# zanetti : zanetti
# lampaui : lampau
# menghadiri : hadir
# berkumpul : kumpul
# bersorak : sorak
# sorai : sorai
# menyalakan : nyala
# flare : flare
# cahaya : cahaya
# ponsel : ponsel
# rebut : rebut
# nyemplung : nyemplung
# kolam : kolam
# bruno : bruno
# fernandes : fernandes
# casemiro : casemiro
# maguire : maguire
# skorsing : skorsing
# wak : wak
# haji : haji
# batitusta : batitusta
# ballboy : ballboy
# barang : barang
# kenang : kenang
# maxi : maxi
# rodriguez : rodriguez
# keita : keita
# hamstring : hamstring
# puncak : puncak
# sederet : deret
# pesohor : sohor
# ternama : nama
# meksiko : meksiko
# jurulatih : jurulatih
# berpengalaman : alam
# menolak : tolak
# desas : desas
# desus : desus
# tersingkir : singkir
# suku : suku
# chemistry : chemistry
# berjabat : jabat
# dembele : dembele
# mencontoh : contoh
# bersamaan : sama
# totalitas : totalitas
# flouman : flouman
# nanggung : nanggung
# rtmklik : rtmklik
# sahih : sahih
# rtm : rtm
# mengenal : kenal
# gelontorkan : gelontor
# tirai : tirai
# ditutup : tutup
# hikmah : hikmah
# petik : petik
# berhubungan : hubung
# erat : erat
# turnament : turnament
# ovo : ovo
# gopay : gopay
# detikcom : detikcom
# berkesempatan : sempat
# meliput : liput
# dirangkum : rangkum
# pocket : pocket
# mancis : mancis
# sni : sni
# import : import
# filipin : filipin
# redi : redi
# lewati : lewat
# makna : makna
# andres : andres
# memuji : puji
# keteguhan : teguh
# prinsip : prinsip
# mempertahankan : tahan
# budayanya : budaya
# modernisasi : modernisasi
# adat : adat
# istiadatnya : istiadat
# penyelengaraan : penyelengaraan
# india : india
# pembawa : bawa
# didampingi : damping
# iker : iker
# casillas : casillas
# menampilkan : tampil
# cantik : cantik
# pemandangan : pandang
# menara : menara
# jaber : jaber
# sehari : hari
# tolol : tolol
# liat : liat
# mengomentari : komentar
# minded : minded
# berpikiran : pikir
# terbuka : buka
# berpikir : pikir
# stuuu : stuuu
# lgbtq : lgbtq
# people : people
# sembang : sembang
# santai : santai
# ybtm : ybtm
# kbs : kbs
# belia : belia
# melaka : melaka
# melambung : lambung
# bentar : bentar
# langkawifm : langkawifm
# congrats : congrats
# menepis : menep
# jujur : jujur
# youtuber : youtuber
# betah : betah
# yeayyy : yeayyy
# mengaku : aku
# diterapkan : terap
# pas : pas
# ejekan : ejek
# stigma : stigma
# penyelamatan : selamat
# super : super
# sanjung : sanjung
# rahasia : rahasia
# cuplikan : cuplik
# syekh : syekh
# tendangan : tendang
# alih : alih
# kebobolan : bobol
# marroko : marroko
# mendungkung : mendungkung
# gebyar : gebyar
# menundukkan : tunduk
# hattrick : hattrick
# dbanding : dbanding
# pemuncak : puncak
# deserve : deserve
# had : had
# dunyya : dunyya
# takluk : takluk
# lioris : lioris
# tinju : tinju
# seragam : seragam
# bantah : bantah
# jin : jin
# vulgarnya : vulgar
# aktivis : aktivis
# palestin : palestin
# muna : muna
# el : el
# kurd : kurd
# tribun : tribun
# tamu : tamu
# mjd : mjd
# menjalankan : jalan
# singkat : singkat
# mengancam : ancam
# komentar : komentar
# indihome : indihome
# fina : fina
# economic : economic
# zone : zone
# rangkaian : rangkai
# lokal : lokal
# memasuki : pasuk
# seiring : iring
# paulo : paulo
# dilarang : larang
# seksi : seksi
# cewek : cewek
# hukuman : hukum
# trivia : trivia
# dihadiahkan : hadiah
# testimoni : testimoni
# dipermalukan : malu
# berhijab : hijab
# aisha : aisha
# misi : misi
# inspiratif : inspiratif
# penampilannya : tampil
# bukti : bukti
# penyokong : sokong
# memenuhi : penuh
# place : place
# concorde : concorde
# situ : situ
# terbang : terbang
# torehan : toreh
# back : back
# meluncurkan : luncur
# menangkan : menang
# campeones : campeones
# del : del
# mundo : mundo
# ragam : ragam
# alkohol : alkohol
# ceo : ceo
# sundar : sundar
# pichai : pichai
# pai : pai
# sambutan : sambut
# mengukir : ukir
# terakbar : akbar
# jung : jung
# kook : kook
# membawakan : bawa
# fahad : fahad
# kubaisi : bais
# off : off
# bayt : bayt
# khor : khor
# army : army
# gelisah : gelisah
# septet : septet
# pop : pop
# menemaninya : teman
# kim : kim
# jong : jong
# un : un
# aparat : aparat
# represif : represif
# didalam : dalam
# diluar : luar
# salut : salut
# mls : mls
# sepurane : sepurane
# cak : cak
# telat : telat
# memukau : pukau
# pejabat : jabat
# pengerusi : pengerusi
# jawatankuasa : jawatankuasa
# multimedia : multimedia
# ngo : ngo
# perak : perak
# kerjasama : kerjasama
# digital : digital
# agensi : agens
# pknp : pknp
# jabatan : jabat
# penyiaran : siar
# sukacita : sukacita
# dhaka : dhaka
# kebahagiaan : bahagia
# kesulitan : sulit
# ekonomi : ekonomi
# penderitaan : derita
# ngikutin : ngikutin
# bener : bener
# hafal : hafal
# golnya : gol
# mengamati : amat
# memotong : potong
# kedudukan : duduk
# belgium : belgium
# tipsy : tipsy
# tuesday : tuesday
# dj : dj
# band : band
# december : december
# contact : contact
# for : for
# unggah : unggah
# melaporkan : lapor
# insiden : insiden
# bersitegang : bersitegang
# macron : macron
# arrigo : arrigo
# sacchi : sacchi
# dibandingkan : banding
# takhta : takhta
# generasi : generasi
# dibicarakan : bicara
# dipanggil : panggil
# joko : joko
# galih : galih
# mal : mal
# jababeka : jababeka
# ruko : ruko
# ortu : ortu
# bapack : bapack
# m : m
# love : love
# with : with
# ...
# terduduk : duduk
# lesu : lesu
# afp : afp
# figur : figur
# anies : anies
# baswedan : baswedan
# ganjar : ganjar
# ferdy : ferdy
# sambo : sambo
# sandiaga : sandiaga
# uno : uno
# arg : arg
# amblas : amblas
# malakat : malakat
# big : big
# screen : screen
# mall : mall
# teruskan : terus
# ambisius : ambisius
# akademi : akademi
# blistener : blistener
# finally : finally
# did : did
# job : job
# seleb : seleb
# wayahe : wayahe
# makaryo : makaryo
# bergaransi : garansi
# sparepart : sparepart
# komplit : komplit
# buenoe : buenoe
# membiarkan : biar
# politisasi : politisasi
# pemilu : milu
# rungkad : rungkad
# pertandingannya : tanding
# nbsp : nbsp
# diperdebatkan : debat
# pinjem : pinjem
# fix : fix
# magetan : magetan
# collaborative : collaborative
# space : space
# mcs : mcs
# legendaris : legendaris
# menyukseskan : sukses
# powered : powered
# audacy : audacy
# klimaks : klimaks
# ndplace : ndplace
# memboyong : boyong
# jokowisyoo : jokowisyoo
# siswadi : siswadi
# biodata : biodata
# inti : inti
# pressure : pressure
# terseru : seru
# kaki : kaki
# rindukan : rindu
# parabolaku : parabola
# mempercayai : percaya
# mengisi : isi
# paket : paket
# voucher : voucher
# ehmm : ehmm
# bombastis : bombastis
# trilliun : trilliun
# berpelukan : peluk
# satudesa : satudesa
# bandar : bandar
# gacorrr : gacorrr
# depo : depo
# dihibur : hibur
# raihan : raih
# imin : imin
# diprotes : protes
# meramaikan : ramai
# berbangga : bangga
# bulukumba : bulukumba
# jamuan : jamu
# berhutang : hutang
# padamu : pada
# bagikan : bagi
# kebersamaanya : kebersamaanya
# kain : kain
# monumen : monumen
# obelisco : obelisco
# reuters : reuters
# agustin : agustin
# marcarian : marcarian
# ulangi : ulang
# perpisahan : pisah
# kuasai : kuasa
# award : award
# garis : garis
# tepi : tepi
# persia : sia
# memajukan : maju
# gerus : gerus
# juooss : juooss
# mikrofon : mikrofon
# penaltinya : penalti
# duduk : duduk
# samping : samping
# menantu : menantu
# donald : donald
# trump : trump
# keaslian : asli
# benarkan : benar
# untungan : untung
# indosiar : indosiar
# gula : gula
# tensi : tensi
# mengukuhkan : kukuh
# diwilayah : wilayah
# bontang : bontang
# excited : excited
# dipermasalahkan : masalah
# wise : wise
# warbiyasak : warbiyasak
# menurutku : turut
# adem : adem
# sblumnya : sblumnya
# berkelas : kelas
# suratan : surat
# mahal : mahal
# omedetou : omedetou
# art : art
# haku : haku
# impiannya : impi
# relawan : rawan
# pikir : pikir
# dibayar : bayar
# yandex : yandex
# mudah : mudah
# kembarbola : kembarbola
# loser : loser
# promo : promo
# finalti : finalti
# don : don
# cry : cry
# triple : triple
# nutmeg : nutmeg
# kecup : kecup
# km : km
# sbgai : sbgai
# kaya : kaya
# rumahnya : rumah
# hatinya : hati
# keberhasilannya : hasil
# spekulasi : spekulasi
# masmen : masmen
# merata : rata
# melulu : melulu
# khalifa : khalifa
# pertarungan : tarung
# iii : iii
# iv : iv
# borong : borong
# bee : bee
# kompas : kompas
# abadi : abadi
# kejar : kejar
# kejaran : kejar
# fansclub : fansclub
# higuain : higuain
# epic : epic
# tep : tep
# bang : bang
# kemanangan : kemanangan
# tertajam : tajam
# menekuk : tekuk
# playoff : playoff
# abaya : abaya
# faz : faz
# bayaran : bayar
# icymi : icymi
# atmosfer : atmosfer
# cemerlang : cemerlang
# speechless : speechless
# lu : lu
# keknya : kek
# kedepan : depan
# deg : deg
# degan : degan
# berprestasi : prestasi
# ketum : tum
# bergembira : gembira
# dibilang : bilang
# manapun : mana
# palestine : palestine
# solidaritasnya : solidaritas
# mengkhianati : khianat
# pepatah : pepatah
# menggambarkan : gambar
# jazair : jazair
# khadija : khadija
# ben : ben
# qena : qena
# presenter : presenter
# jazeera : jazeera
# khatam : khatam
# pastikan : pasti
# pln : pln
# jamin : jamin
# listrik : listrik
# kariermu : karier
# trio : trio
# kukuhkan : kukuh
# lonceng : lonceng
# kepahlawanannya : pahlawan
# leomessi : leomessi
# kerasmu : keras
# tertunda : tunda
# cnbc : cnbc
# kepastian : pasti
# totogel : totogel
# togel : togel
# casino : casino
# berpihak : pihak
# factos : factos
# menciptakan : cipta
# pmnangnya : pmnangnya
# enth : enth
# klian : klian
# prmainan : prmainan
# sngt : sngt
# td : td
# malem : malem
# akhrnya : akhrnya
# estafet : estafet
# faktanya : fakta
# medsosnya : medsosnya
# perkataan : kata
# mencengangkan : cengang
# dlanjutkn : dlanjutkn
# brmain : brmain
# kmbali : kmbali
# pnuh : pnuh
# pnutupan : pnutupan
# oke : oke
# insyaallah : insyaallah
# dijalan : jalan
# dielu : elu
# elukan : elu
# lombakan : lomba
# max : max
# ii : ii
# digemakan : gema
# memperbolehkan : boleh
# atribut : atribut
# dipamerkan : pamer
# cancel : cancel
# utamanya : utama
# guardian : guardian
# ngeberitain : ngeberitain
# pererebutan : rebut
# halangi : halang
# menyangka : sangka
# tersukses : sukses
# pulau : pulau
# bungin : bungin
# ve : ve
# seen : seen
# disamping : samping
# galau : galau
# rasain : rasain
# keulang : ulang
# thank : thank
# disabet : sabet
# kategori : kategori
# diwujudkan : wujud
# sentiasa : sentiasa
# nikmat : nikmat
# menyokong : sokong
# abis : abis
# menegas : tegas
# skore : skore
# summarecon : summarecon
# serpong : serpong
# kelapa : kelapa
# area : area
# menayangkan : tayang
# dipadati : padat
# overall : overall
# unexpected : unexpected
# diragukan : ragu
# persatu : satu
# underdog : underdog
# unggulan : unggul
# ricardinho : ricardinho
# mohon : mohon
# terimalah : terima
# restu : restu
# ilahi : ilahi
# yme : yme
# dikenang : kenang
# xmenit : xmenit
# bru : bru
# mutlak : mutlak
# mnjijikan : mnjijikan
# memuakan : mua
# dibnggakan : dibnggakan
# hrusnya : hrusnya
# bngga : bngga
# jdi : jdi
# brthan : brthan
# sumbang : sumbang
# tempati : tempat
# podium : podium
# dam : dam
# gaada : gaada
# biasaa : biasaa
# rekap : rekap
# mentereng : mentereng
# bsok : bsok
# lum : lum
# tntu : tntu
# palgi : palgi
# mrsa : mrsa
# thx : thx
# halal : halal
# pialanya : piala
# peluk : peluk
# sahhhhh : sahhhhh
# tolong : tolong
# bandingin : bandingin
# ce : ce
# r : r
# sps : sps
# kepri : kepri
# mewakili : wakil
# acehkini : acehkini
# bsa : bsa
# klah : klah
# dri : dri
# draw : draw
# tndanya : tndanya
# bukanklah : bukanklah
# bagiku : bagi
# personil : personil
# denpasar : denpasar
# wilhum : wilhum
# denbar : denbar
# merengkuh : rengkuh
# tendang : tendang
# wjar : wjar
# emanuel : emanuel
# twiteran : twiteran
# menangnya : menang
# kcuali : kcuali
# mnt : mnt
# mbapep : mbapep
# selesaikan : selesai
# nontonya : nontonya
# dilatih : latih
# nyenyak : nyenyak
# kanjuruhan : kanjuruhan
# kukira : kira
# pantengin : pantengin
# parah : parah
# wlaupun : wlaupun
# nunggunya : nunggunya
# smoga : smoga
# msih : msih
# didunia : dunia
# memories : memories
# gotze : gotze
# south : south
# africa : africa
# german : german
# materazzi : materazzi
# kebanyakan : banyak
# unsur : unsur
# inisial : inisial
# sepakbolanya : sepakbolanya
# ultah : ultah
# hitungan : hitung
# gpp : gpp
# untul : untul
# terhibur : hibur
# laksana : laksana
# filmnya : film
# film : film
# serigala : serigala
# nyesek : nyesek
# argen : argen
# mengalahkannya : kalah
# hiburannya : hibur
# memperbaiki : baik
# rusak : rusak
# nataru : nataru
# promonya : promonya
# senangg : senangg
# sekalii : sekali
# vamoss : vamoss
# after : after
# their : their
# smiling : smiling
# faces : faces
# what : what
# pede : pede
# hapus : hapus
# kereta : kereta
# ds : ds
# kebalikannya : balik
# valid : valid
# yassine : yassine
# bounou : bounou
# diminati : mati
# kost : kost
# seruan : seru
# ngakak : ngakak
# ketemu : ketemu
# entar : entar
# aamiin : aamiin
# videocall : videocall
# nyemangatin : nyemangatin
# cc : cc
# frontline : frontline
# pc : pc
# sosmed : sosmed
# kkasih : kkasih
# kep : kep
# lhokseumawe : lhokseumawe
# aceh : aceh
# seruu : seruu
# ajig : ajig
# pembenci : benci
# perwujutan : perwujutan
# bakat : bakat
# simpel : simpel
# doubt : doubt
# got : got
# makasih : makasih
# lm : lm
# harii : hari
# siapsiap : siapsiap
# pengesahan : kesah
# livakovic : livakovic
# szczesny : szczesny
# munculnya : muncul
# finalis : final
# wattunnami : wattunnami
# tawwa : tawwa
# mi : mi
# grizmann : grizmann
# luca : luca
# mami : mami
# ta : ta
# bunda : bunda
# putranya : putra
# kapitan : kapitan
# saudaranya : saudara
# definisi : definisi
# hakiki : hakiki
# kutukan : kutu
# keliatan : liat
# happy : happy
# klovers : klovers
# victory : victory
# vamoos : vamoos
# argentinaa : argentinaa
# wordp : wordp
# josss : josss
# menariknya : tarik
# salahnya : salah
# nganggep : nganggep
# sarat : sarat
# anjir : anjir
# gayeng : gayeng
# oyak : oyak
# melakukannya : laku
# terwujud : wujud
# ambik : ambik
# ko : ko
# suasano : suasano
# morocco : morocco
# padu : padu
# bergaya : gaya
# sokong : sokong
# wkt : wkt
# nntn : nntn
# ngomong : ngomong
# yaa : yaa
# today : today
# suana : suana
# nyeletuk : nyeletuk
# menjurai : jurai
# netflix : netflix
# sbspremium : sbspremium
# taklukkan : takluk
# kontras : kontras
# perbandingan : banding
# ekspresi : ekspresi
# bukansipalingbola : bukansipalingbola
# yuhuuuu : yuhuuuu
# padati : padat
# merdeka : merdeka
# meulaboh : meulaboh
# emilio : emilio
# menuntaskan : tuntas
# julian : juli
# alvarez : alvarez
# berpendapat : dapat
# hayyaa : hayyaa
# hayyaaa : hayyaaa
# credit : credit
# albileceste : albileceste
# nontonnya : nontonnya
# stabil : stabil
# aet : aet
# penalties : penalties
# eksekutor : eksekutor
# penentu : tentu
# idn : idn
# fact : fact
# ca : ca
# hatur : hatur
# nuhun : nuhun
# sugema : sugema
# tuntaskan : tuntas
# kbayang : kbayang
# ngawal : ngawal
# lemburan : lembur
# menghentikan : henti
# iya : iya
# try : try
# ma : ma
# wkwkwkwk : wkwkwkwk
# ajaaa : ajaaa
# seumur : umur
# startnya : start
# tapii : tapi
# begadang : begadang
# mlu : mlu
# skrng : skrng
# terimah : terimah
# validasi : validasi
# yeahhhhh : yeahhhhh
# besok : besok
# yok : yok
# sekeluarga : keluarga
# sakit : sakit
# lemah : lemah
# mengurutkan : urut
# germany : germany
# yessss : yessss
# whole : whole
# penyelenggaran : penyelenggaran
# long : long
# wait : wait
# over : over
# pensiunnya : pensiun
# seksyen : seksyen
# shah : shah
# alam : alam
# congratss : congratss
# sepakbolannya : sepakbolannya
# fance : fance
# well : well
# laeeb : laeeb
# really : really
# cool : cool
# mencatat : catat
# huraaaaa : huraaaaa
# pulanh : pulanh
# russia : russia
# ntar : ntar
# indonesianya : indonesia
# gokil : gokil
# memorable : memorable
# diisi : isi
# masyaallah : masyaallah
# end : end
# last : last
# dance : dance
# p : p
# mitsubishi : mitsubishi
# electric : electric
# kena : kena
# panglima : panglima
# divisi : divisi
# infanteri : infanteri
# kostrad : kostrad
# tniadmengabdidanmembangunbersamarakyat : tniadmengabdidanmembangunbersamarakyat
# angkatan : angkat
# darat : darat
# hpku : hpku
# diwa : diwa
# tmen : tmen
# kontaku : kontaku
# ttg : ttg
# mesti : mesti
# sepii : sepi
# hmmm : hmmm
# gede : gede
# mauricio : mauricio
# agentina : agentina
# arc : arc
# plot : plot
# konflik : konflik
# panutan : panutan
# bolanya : bola
# baginya : bagi
# kasut : kasut
# penjaring : jaring
# planet : planet
# darul : darul
# takzim : takzim
# vakum : vakum
# ekspresinya : ekspresi
# b : b
# mesir : mesir
# melampaui : lampau
# halo : halo
# muara : muara
# sabak : sabak
# narkotika : narkotika
# dibu : dibu
# kontroversial : kontroversial
# closingnya : closingnya
# untukmu : untuk
# rasmi : rasmi
# ditarik : tarik
# senam : senam
# pertahanan : tahan
# kubu : kubu
# tetep : tetep
# ss : ss
# lazio : lazio
# grande : grande
# legecy : legecy
# kesabaran : sabar
# market : market
# latepost : latepost
# diremehkan : remeh
# adl : adl
# menggondol : gondol
# membekuk : bekuk
# dihadirkan : hadir
# warm : warm
# welcome : welcome
# terkeren : keren
# sebanding : banding
# dikeluarkan : keluar
# berdamai : damai
# masyarkat : masyarkat
# indonsia : indonsia
# barcelona : barcelona
# disponsorin : disponsorin
# foundation : foundation
# airways : airways
# pengumuman : umum
# sugeng : sugeng
# dalu : dalu
# ending : ending
# sipaling : sipaling
# emyu : emyu
# gilaaaa : gilaaaa
# permainannya : main
# kereenn : kereenn
# your : your
# my : my
# heart : heart
# bep : bep
# coz : coz
# apapun : apa
# much : much
# wkwkkw : wkwkkw
# trofinya : trofi
# emtek : emtek
# dipotong : potong
# iklan : iklan
# dadi : dadi
# sangar : sangar
# cuaca : cuaca
# dicek : cek
# yukk : yukk
# produk : produk
# rekomendasinya : rekomendasi
# disuguhin : disuguhin
# membosankan : bosan
# ngapa : ngapa
# topscorer : topscorer
# kai : kai
# fontaine : fontaine
# mengembalikan : kembali
# senyuman : senyum
# jkt : jkt
# unpredictable : unpredictable
# ngecarry : ngecarry
# predictable : predictable
# ampas : ampas
# duluan : duluan
# skuadnya : skuadnya
# adlh : adlh
# exclusive : exclusive
# sapat : sapat
# gapleh : gapleh
# balak : balak
# croissant : croissant
# kompek : kompek
# tagar : tagar
# pesimis : pesimis
# ngehek : ngehek
# ggwp : ggwp
# hidupku : hidup
# tumbang : tumbang
# pelangi : pelangi
# butex : butex
# en : en
# islamophobia : islamophobia
# nyolok : nyolok
# sebelah : belah
# sportifitas : sportifitas
# agenda : agenda
# jumawa : jumawa
# sunyi : sunyi
# rameee : rameee
# gilang : gilang
# minit : minit
# dijaringkan : jaring
# le : le
# bleu : bleu
# {'qatar': 'qatar', 'university': 'university', 'mengumumkan': 'umum', 'kamar': 'kamar', 'ditempati': 'tempat', 'lionel': 'lionel', 'messi': 'messi', 'gelaran': 'gelar', 'piala': 'piala', 'dunia': 'dunia', 'diubah': 'ubah', 'museum': 'museum', 'mini': 'mini', 'kampus': 'kampus', 'kamp': 'kamp', 'timnas': 'timnas', 'argentina': 'argentina', 'kemarin': 'kemarin', 'puan': 'puan', 'maharani': 'maharani', 'berharap': 'harap', 'berjalan': 'jalan', 'lancar': 'lancar', 'harapan': 'harap', 'rakyat': 'rakyat', 'stadion': 'stadion', 'mewah': 'mewah', 'canggih': 'canggih', 'sri': 'sri', 'mulyani': 'mulyani', 'mama
ia': 'asia', 'berasingan': 'asing', 'digabungkan': 'gabung', 'rantau': 'rantau', 'bersaing': 'saing', 'peringkat': 'peringkat', 'benua': 'benua', 'top': 'top', 'idea': 'idea', 'terpulang': 'pulang', 'badan': 'badan', 'bolasepak': 'bolasepak', 'jurang': 'jurang', 'dirapatkan': 'rapat', 'buktikan': 'bukti', 'nia': 'nia', 'ramadhani': 'ramadhani', 'hobi': 'hobi', 'voting': 'voting', 'suara': 'suara', 'menempatkan': 'tempat', 'lusail': 'lusail', 'kota': 'kota', 'terbesar': 'besar', 'terletak': 'letak', 'pesisir': 'pesisir', 'selatan': 'selatan', 'provinsi': 'provinsi', 'al': 'al', 'daayen': 'daayen', 'pemerintah': 'perintah', 'merombak': 'rombak', 'dana': 'dana', 'miliar': 'miliar', 'dollar': 'dollar', 'serikat': 'serikat', 'hasil': 'hasil', 'nobatkan': 'nobat', 'pembongkaran': 'bongkar', 'sepak': 'sepak', 'bola': 'bola', 'ras': 'ras', 'abu': 'abu', 'aboud': 'aboud', 'doha': ...
# ------------------------

# %%
# Fungsi untuk mengaplikasikan hasil stemming ke dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

# %%
df['data_stemming'] = df['data_stopwords'].apply(get_stemmed_term)

# %%
df['data_text_bersih'] = df['data_stemming'].apply(lambda x: ' '.join(x))

# %%
df[['data_stopwords','data_stemming','data_text_bersih']]
# Out:
#                                          data_stopwords  \
# 0     [qatar, university, mengumumkan, kamar, ditemp...
# 1     [puan, maharani, berharap, gelaran, piala, dun...
# 2     [stadion, mewah, canggih, piala, dunia, qatar,...
# 3     [kh, chudlori, gus, dur, piala, dunia, qatar, ...
# 4     [puan, maharani, berharap, gelaran, piala, dun...
# ...                                                 ...
# 2654  [final, istimewa, piala, dunia, qatar, selamat...
# 2655  [tumbang, pendukung, pelangi, butex, en, islam...
# 2656  [digadang, piala, dunia, sunyi, karna, kontrov...
# 2657  [selamat, argentina, kemenangannya, piala, dun...
# 2658  [argentina, lionel, messi, menangis, selepas, ...
#
#                                           data_stemming  \
# 0     [qatar, university, umum, kamar, tempat, lione...
# 1     [puan, maharani, harap, gelar, piala, dunia, q...
# 2     [stadion, mewah, canggih, piala, dunia, qatar,...
# 3     [kh, chudlori, gus, dur, piala, dunia, qatar, ...
# 4     [puan, maharani, harap, gelar, piala, dunia, q...
# ...                                                 ...
# 2654  [final, istimewa, piala, dunia, qatar, selamat...
# 2655  [tumbang, dukung, pelangi, butex, en, islamoph...
# 2656  [gadang, piala, dunia, sunyi, karna, kontrover...
# 2657  [selamat, argentina, menang, piala, dunia, qatar]
# 2658  [argentina, lionel, messi, menang, lepas, juar...
#
#                                        data_text_bersih
# 0     qatar university umum kamar tempat lionel mess...
# 1     puan maharani harap gelar piala dunia qatar ja...
# 2     stadion mewah canggih piala dunia qatar sri mu...
# 3     kh chudlori gus dur piala dunia qatar gus ch y...
# 4     puan maharani harap gelar piala dunia qatar ja...
# ...                                                 ...
# 2654  final istimewa piala dunia qatar selamat argen...
# 2655  tumbang dukung pelangi butex en islamophobia n...
# 2656  gadang piala dunia sunyi karna kontroversi pia...
# 2657         selamat argentina menang piala dunia qatar
# 2658  argentina lionel messi menang lepas juara pial...
#
# [2655 rows x 3 columns]

# %% [markdown]
# ##**Menyimpan data setelah text preprocessing**

# %%
filename = 'Data_Twitter_Bersih.csv'
df.to_csv(filename, index=False)

# %% [markdown]
# # **Visualisasi Frekuensi Kata**
#
# Dilakukan visualisasi frekuensi keseluruhan kata menggunakan wordcloud. Kemudian dilakukan pemisahan visualisasi frekuensi kata menjadi positif dan negatif, untuk mengetahui jumlah kata dari masing-masing sentimen menggunakan wordcloud.

# %%
# Menampilkan keseluruhan frekuensi kata hasil dari text processing dengan wordcloud
wordcloud = WordCloud(width=1600, height=800, max_font_size=200, stopwords=list_stopwords, background_color="white").generate(list_to_text)

plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Word Cloud
# 10 Kata teratas yang paling sering digunakan adalah:
#  "piala dunia"
#  "dunia qatar"
#  "argentina"
#  "juara piala"
#  "qatar"
#  "final piala"
#  "lionel messi"
#  "messi"
#  "argentina juara"
#  "prancis"

# %% [markdown]
# #**Labelling Data**

# %%
# !wget https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/Data_Twitter_Pildun_Bersih.csv -O Data_Twitter_Pildun_Bersih.csv
# !wget https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/lexicon_negative.csv -O lexicon_negative.csv
# !wget https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/lexicon_positive.csv -O lexicon_positive.csv
# Out:
# --2023-11-16 14:34:47--  https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/Data_Twitter_Pildun_Bersih.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187984 (184K) [text/plain]
# Saving to: ‘Data_Twitter_Pildun_Bersih.csv’
#
# Data_Twitter_Pildun 100%[===================>] 183.58K  --.-KB/s    in 0.005s
#
# 2023-11-16 14:34:47 (34.8 MB/s) - ‘Data_Twitter_Pildun_Bersih.csv’ saved [187984/187984]
#
# --2023-11-16 14:34:47--  https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/lexicon_negative.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82684 (81K) [text/plain]
# Saving to: ‘lexicon_negative.csv’
#
# lexicon_negative.cs 100%[===================>]  80.75K  --.-KB/s    in 0.004s
#
# 2023-11-16 14:34:47 (20.9 MB/s) - ‘lexicon_negative.csv’ saved [82684/82684]
#
# --2023-11-16 14:34:47--  https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/lexicon_positive.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41351 (40K) [text/plain]
# Saving to: ‘lexicon_positive.csv’
#
# lexicon_positive.cs 100%[===================>]  40.38K  --.-KB/s    in 0.002s
#
# 2023-11-16 14:34:48 (23.1 MB/s) - ‘lexicon_positive.csv’ saved [41351/41351]

# %%
tweets = []

with open('Data_Twitter_Bersih.csv', 'r') as csvfile:
  reader = csv.reader(csvfile, delimiter=',')
  for row in reader:
    tweet= dict()
    tweet['tweet_bersih'] = row[42]
    tweets.append(tweet)

# %%
lexicon_positive = dict()
lexicon_negative = dict()

# %%
# Membaca file CSV 'lexicon.csv' dan menyimpan isinya ke dalam dictionary 'lexicon_positive
with open('lexicon_positive.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_positive[row[0]] = int(row[1])

with open('lexicon_negative.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        lexicon_negative[row[0]] = int(row[1])

# %%
for tweet in tweets:
    score = 0
    for word in tweet['tweet_bersih'].split():
        if word in lexicon_positive:
            score = score + lexicon_positive[word]

    for word in tweet['tweet_bersih'].split():
        if word in lexicon_negative:
            score = score + lexicon_negative[word]

    tweet['score'] = score
    if (score > 0):
        tweet['sentiment'] = 'positive'
    elif (score < 0):
        tweet['sentiment'] = 'negative'
    else:
        tweet['sentiment'] = 'neutral'

# %%
tweets
# Out:
# [{'tweet_bersih': 'data_text_bersih', 'score': 0, 'sentiment': 'neutral'},
#  {'tweet_bersih': 'qatar university umum kamar tempat lionel messi gelar piala dunia ubah museum mini kampus kamp timnas argentina piala dunia kemarin',
#   'score': -2,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'stadion mewah canggih piala dunia qatar sri mulyani mama awards',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'kh chudlori gus dur piala dunia qatar gus ch youtube',
#   'score': -1,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'kylian mbappe bangkit gagal piala dunia qatar',
#   'score': -7,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'argentina doooooooong admin',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'puan maharani harap gelar piala dunia qatar jalan lancar puan harap rakyat',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'saksi bisu piala dunia kamar lionel messi qatar sulap museum mini',
#   'score': -2,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'kamar messi qatar ubah museum',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'mini museum kelola qatar university mess basecamp timnas gelar piala dunia jadi kamar leo messi museum mini yup gambar kamar timnas argentina leo messi qatar',
#   'score': -1,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'saksi bisu sejarah piala dunia kamar lionel messi qatar sulap museum mini',
#   'score': -2,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'saksi bisu sejarah piala dunia kamar lionel messi qatar sulap museum mini',
#   'score': -2,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'kabar barat fenomena orang orang beli bidet semprot pulang qatar pasca nonton piala dunia',
#   'score': -8,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'dunia', 'score': -1, 'sentiment': 'negative'},
#  {'tweet_bersih': 'cetak gol tua piala dunia saja messi ronaldo sports sports',
#   'score': -5,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'masuk akal fifa atur argentina juara piala dunia piala dunia qatar baik',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'prediksi piala aff timnas indonesia vs thailand desember link claim bonus deposit k deposit pulsa potong',
#   'score': -5,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'messi dewa kamar hotel kapten timnas argentina piala dunia qatar museum',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'kamar lionel messi inap piala dunia jadi museum',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'stadion mewah canggih piala dunia qatar',
#   'score': -1,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'wni volunteer piala dunia qatar duta bangsa',
#   'score': -1,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'tweet argentina juara pinalti prancis bapuk piala dunia selenggara qatar salah mas gibran',
#   'score': -2,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'stadion piala dunia qatar bahan bekas baifern kendali imei',
#   'score': -3,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'kamar hotel messi piala dunia qatar ubah museum',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'gilir amerika syarikat tuan rumah lantang buruk qatar tanding rekod',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'besar gaji piala dunia qatar',
#   'score': 1,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'wni volunteer piala dunia qatar duta bangsa',
#   'score': -1,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'congratulations argentina hasil mnjdi juara fifa world cup qatar piala dunia vamous argentina dn sukses main baik lionel messi vamous',
#   'score': 7,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'pulang benzema jelang laga perdana piala dunia picu polemik',
#   'score': 5,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'piala dunia qatar nobat piala dunia baik abad',
#   'score': 0,
#   'sentiment': 'neutral'},
#  {'tweet_bersih': 'ayam burger king qatar piala dunia',
#   'score': -1,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'pilih qatar tuan rumah piala dunia timbul publik pasal qatar catat buruk kait isu hak asasi manusia qatar pilih tuan rumah piala dunia',
#   'score': -15,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'ubah tahap layak piala asia piala dunia asing gabung rantau saing peringkat benua top piala asia piala dunia idea pulang badan bolasepak jurang rapat qatar bukti',
#   'score': -12,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'stadion piala dunia qatar bahan bek

#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'stadion piala dunia qatar bahan bekas baifern kendali imei',
#   'score': -3,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'rakyat argentina sambut pulang pahlawan gores tinta emas piala dunia qatar presiden alberto fernandez umum sambut lionel messi dkk libur nasional',
#   'score': 10,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'jejak argentina cetak mega bintang lapang hijau news',
#   'score': 6,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'fakta unik tarik kompetisi piala dunia qatar',
#   'score': -2,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'stadion mewah canggih piala dunia qatar sri mulyani mama awards',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'stadion mewah canggih piala dunia qatar sri mulyani mama awards',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'pecah nonton bareng teroooss jakarta saksi messi angkat trofi piala dunia qatar',
#   'score': 3,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'alas qatar bisht messi seremoni juara piala dunia cnn indonesia google berita olahraga',
#   'score': -5,
#   'sentiment': 'negative'},
#  {'tweet_bersih': 'yess topik piala dunia tarik tulis gimana udah ancang nulis pildun',
#   'score': 1,
#   'sentiment': 'positive'},
#  {'tweet_bersih': 'lionel messi main argentina angkat trofi piala dunia juara piala dunia lusail stadium qatar senin',
#   'score': 1,
#   'sentiment': 'positive'},
#  ...]

# %% [markdown]
# ##**Mengubah hasil tweets menjadi dataframe**

# %%
datas = pd.DataFrame.from_dict(tweets)

# %%
print(datas['sentiment'].value_counts())
# Out:
# negative    1387
# positive    1014
# neutral      255
# Name: sentiment, dtype: int64

# %% [markdown]
# #**Modelling**

# %%
datas.head()
# Out:
#                                         tweet_bersih  score sentiment
# 0                                   data_text_bersih      0   neutral
# 1  qatar university umum kamar tempat lionel mess...     -2  negative
# 2  puan maharani harap gelar piala dunia qatar ja...      3  positive
# 3  stadion mewah canggih piala dunia qatar sri mu...      3  positive
# 4  kh chudlori gus dur piala dunia qatar gus ch y...     -1  negative

# %%
# Menambahkan library untuk menghitung tf-idf
from sklearn.feature_extraction.text import TfidfVectorizer

# Memanggil library TfidfVectorizer
vectorizer = TfidfVectorizer()

# Konversi teks menjadi vektor menggunakn fit_transform
X = vectorizer.fit_transform(datas['tweet_bersih'].values.astype('U'))

# Membuat label untuk modelling
y = datas['sentiment']

# %% [markdown]
# ## **Membuat model dan evaluasi menggunakan Multinominal Naive Bayes**
# Tahap ini merupakan tahap membuat model dan evaluasi. Model yang digunakan adalah Multinomial Naive Bayes yang biasa digunakan dalam klasifikasi teks.
#
# Pada tahap ini dilakukan:
# * Membagi data train dan dan test menjadi 80% dan 20%.
# * Membuat model Multinomial Naive Bayes.
# * Menampilkan confusion matrix, nilai akurasi, recall, dan f1-score.

# %%
# Membagi data training dan data testing (20% data testing dan 80% data training)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
# Menambahkan model library Multinomial Naive Bayes, confusion matrix, dan nilai akurasi
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score

# Memanggil fungsi klasifikasi Naive bayes dan Memasukkan data training pada model
clf = LinearSVC().fit(X_train, y_train)
predicted = clf.predict(X_test)

# Mengukur keberhasilan program menggunakan confusion matrix dan nilai akurasi
cm = (confusion_matrix(y_test, predicted))
ac = (accuracy_score(y_test, predicted))

# %%
# Menampilkan confusion matrix
cm
# Out:
# array([[252,   1,  22],
#        [ 26,  20,  16],
#        [ 27,   2, 166]])

# %%
# Menampilkan visualisasi confusion matrix menggunakan library matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_test, predicted), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_head")
plt.ylabel("y_true")
plt.show()

# %%
# Menampilkan nilai akurasi
print('nilai akurasi modelnya adalah :', ac)
# Out:
# nilai akurasi modelnya adalah : 0.8233082706766918

# %%
# Menghitung nilai akurasi dari klasifikasi naive bayes
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.83      0.92      0.87       275
#      neutral       0.87      0.32      0.47        62
#     positive       0.81      0.85      0.83       195
#
#     accuracy                           0.82       532
#    macro avg       0.84      0.70      0.72       532
# weighted avg       0.83      0.82      0.81       532

# %% [markdown]
# # **Visualisasi**

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt

# %%
# Memisahkan dataframe menjadi dua, yaitu data dengan label positif dan negatif
df_positif = datas[datas['sentiment'] == 'positive']
df_negatif = datas[datas['sentiment'] == 'negative']
df_neutral = datas[datas['sentiment'] == 'neutral']

# %%
# Menggabungkan semua tweet dengan label positif menjadi satu string
all_positif = ' '.join(df_positif['tweet_bersih'])

# Menggabungkan semua tweet dengan label negatif menjadi satu string
all_negatif = ' '.join(df_negatif['tweet_bersih'])

# Menggabungkan semua tweet dengan label neutral menjadi satu string
all_neutral = ' '.join(df_neutral['tweet_bersih'])

# %%
# Membuat wordcloud dari string positif
print('POSITIF\n')
wordcloud = WordCloud().generate(all_positif)

# Menampilkan wordcloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# Membuat wordcloud dari string negatif
print('\nNegatif')
wordcloud = WordCloud().generate(all_negatif)

# Menampilkan wordcloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# Membuat wordcloud dari string negatif
wordcloud = WordCloud().generate(all_neutral)

# Menampilkan wordcloud
print('\nNeutral')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# POSITIF
# Negatif
# Neutral

# %% [markdown]
# **Hasil Sentiment Analysis Positif**
#
# Dari 2656 data, hasil data yang positif sebesar 1014. Dan 10 Kata teratas dari sentiment analysist positif  yang paling sering digunakan adalah:
#  "piala dunia"
#  "dunia qatar"
#  "juara piala"
#  "messi"
#  "argentina juara"
#  "lionel messi"
#  "final piala"
#  "selamat argentina"
#  "timnas argentina"
#  "world cup"
#
# **Hasil Sentiment Analysis Negatif**
#
# Dari 2656 data, hasil data yang negatif sebesar 1387. Dan 10 Kata teratas dari sentiment analysist negatif  yang paling sering digunakan adalah:
#  "piala dunia"
#  "dunia qatar"
#  "juara piala"
#  "argentina"
#  "argentina juara"
#  "final piala"
#  "lionel messi"
#  "stadion piala"
#  "messi"
#  "adu pinalti"
#
# **Hasil Sentiment Analysis Neutral**
#
# Dari 2656 data, hasil data yang netral sebesar 255 Dan 10 Kata teratas dari sentiment analysist netral  yang paling sering digunakan adalah:
#  "piala dunia"
#  "dunia qatar"
#  "world cup"
#  "argentina juara"
#  "argentina"
#  "messi"
#  "juara piala"
#  "qatar"
#  "final piala"
#  "fifa world"

# %%
import networkx as nx

# %%
data = (r'https://raw.githubusercontent.com/jihandikaa/ProjectUAS---Data-Mining-Kelompok-5/main/Data_Twitter_Pildun.csv')

# %%
df = pd.read_csv(url_data)
df
# Out:
#                        id      conversation_id               created_at  \
# 0     1608137397375766529  1608137397375766529  2022-12-28 16:26:47 UTC
# 1     1608118257361518596  1608118257361518596  2022-12-28 15:10:44 UTC
# 2     1608114838815010817  1608114838815010817  2022-12-28 14:57:09 UTC
# 3     1608112598410743814  1608112598410743814  2022-12-28 14:48:15 UTC
# 4     1608111124670709762  1608111124670709762  2022-12-28 14:42:24 UTC
# ...                   ...                  ...                      ...
# 2654  1604539206076108802  1604539206076108802  2022-12-18 18:08:52 UTC
# 2655  1604539185859215361  1604539185859215361  2022-12-18 18:08:47 UTC
# 2656  1604539121526939649  1604539121526939649  2022-12-18 18:08:32 UTC
# 2657  1604539090158096384  1604539090158096384  2022-12-18 18:08:24 UTC
# 2658  1604539089054683136  1604539089054683136  2022-12-18 18:08:24 UTC
#
#             date      time  timezone              user_id         username  \
# 0     2022-12-28  16:26:47         0  1222927522033094656      idextratime
# 1     2022-12-28  15:10:44         0   734582844685705218            58o94
# 2     2022-12-28  14:57:09         0   945591801330597892   harus_kamutahu
# 3     2022-12-28  14:48:15         0   740603423079288832  gusyusufchannel
# 4     2022-12-28  14:42:24         0             36205934   abuv_average88
# ...          ...       ...       ...                  ...              ...
# 2654  2022-12-18  18:08:52         0            142537012    adjie_djithuu
# 2655  2022-12-18  18:08:47         0   926487776081539072     skandalmedia
# 2656  2022-12-18  18:08:32         0            288147069         haijoon_
# 2657  2022-12-18  18:08:24         0  1433831856986738690  andreasyona1601
# 2658  2022-12-18  18:08:24         0             38822788      adliazman__
#
#                                    name place  ... geo source user_rt_id  \
# 0                  Extra Time Indonesia   NaN  ... NaN    NaN        NaN
# 1                                     ★   NaN  ... NaN    NaN        NaN
# 2                       Harus kamu tahu   NaN  ... NaN    NaN        NaN
# 3                     Gus Yusuf Channel   NaN  ... NaN    NaN        NaN
# 4                        Victoria Trice   NaN  ... NaN    NaN        NaN
# ...                                 ...   ...  ...  ..    ...        ...
# 2654                      Aji Widayanto   NaN  ... NaN    NaN        NaN
# 2655  #LawanPropaganda🏴⭐️SkandalMedia⭐️   NaN  ... NaN    NaN        NaN
# 2656                   karan⁷🌻 indigo 💙   NaN  ... NaN    NaN        NaN
# 2657                              Andre   NaN  ... NaN    NaN        NaN
# 2658                                 AA   NaN  ... NaN    NaN        NaN
#
#      user_rt retweet_id  reply_to  retweet_date  translate trans_src  \
# 0        NaN        NaN        []           NaN        NaN       NaN
# 1        NaN        NaN        []           NaN        NaN       NaN
# 2        NaN        NaN        []           NaN        NaN       NaN
# 3        NaN        NaN        []           NaN        NaN       NaN
# 4        NaN        NaN        []           NaN        NaN       NaN
# ...      ...        ...       ...           ...        ...       ...
# 2654     NaN        NaN        []           NaN        NaN       NaN
# 2655     NaN        NaN        []           NaN        NaN       NaN
# 2656     NaN        NaN        []           NaN        NaN       NaN
# 2657     NaN        NaN        []           NaN        NaN       NaN
# 2658     NaN        NaN        []           NaN        NaN       NaN
#
#      trans_dest
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2654        NaN
# 2655        NaN
# 2656        NaN
# 2657        NaN
# 2658        NaN
#
# [2659 rows x 36 columns]

# %% [markdown]
# # **SNA**

# %%
users = df.username.to_list()
tweets = df.tweet.to_list()

# %%
G = nx.Graph() # Graph Kosong Baru
G.add_nodes_from(users)

# %%
print('Banyak vertex = ', G.number_of_nodes())
print('Banyak Edges = ', G.number_of_edges())
# Out:
# Banyak vertex =  1284
# Banyak Edges =  0

# %%
for usr, t in zip(users, tweets):
    mentionS =  re.findall("@([a-zA-Z0-9]{1,15})", t)
    for mention in mentionS:
        if "." not in mention: #skipping emails
            G.add_edge(usr, mention)

print('Banyak vertex = ', G.number_of_nodes())
print('Banyak Edges = ', G.number_of_edges())
print("Export ke GexF untuk di import ke Gephi")
nx.write_gexf(G, "Pildun.gexf")
# Out:
# Banyak vertex =  1437
# Banyak Edges =  311
# Export ke GexF untuk di import ke Gephi

# %% [markdown]
# ![ss gephi 2.png](data:image/png;base64,...)

# %% [markdown]
# **Hasil Social Network Analysis**
#
# GEPHI
# Jumlah vertex/nodes = 1437
# Jumlah edges = 311
#
# Akun dengan degree terbesar: @idextratime
#
# 6 akun paling populer adalah:
# @NewsKemenkummham
# @Kumham
# @FaisolAli2022
# @erickthohir
# @FIFAWorldCup
# @idextratime

# %% [markdown]
# Dapat dilihat bahwa pada perbincangan Piala Dunia Qatar 2022 yang menjadi user yang paling berpengaruh atau centralizer untuk masyarakat indonesia adalah
# @NewsKemenkummham
# @Kumham
# @FaisolAli2022
# @erickthohir
# @FIFAWorldCup
# @idextratime
#
# Namun ketika dianalisis lebih lanjut pemilik akun twitter bernama NewsKemenkummham, Kumham, FaisolAli2022 yang saling berinteraksi satu sama lain ini terdeksi adalah akun "bot,” “spam”, atau “akun palsu,”. Sehingga interaksi yang terjadi antar user tidak asli. Selain itu akun-akun bot tersebut suka memanfaatkan hashtag-hashtag di twitter, misal hashtag yang lagi ramai diperbincangkan adalah #pildun2022, hashtagnya  ini dimanfaatkan agar tweets si akun bot bisa naik dan dilihat banyak orang.
# Dilihat dari pemilik akun twitter bernama erickthohir merupakan akun menteri BUMN yang sering membahas konten-konten (tweets) yang bersifat pro terhadap Pildun.
# Dilihat dari pemilik akun twitter bernama FIFAWorldCup merupakan akun verified Federasi Sepak Bola Internasional yang menyebarkan informasi baik positif, negatif, maupun berita terkait Pildun yang sedang hangat diperbincangkan.
# Dilihat dari pemilik akun twitter bernama idextratime sebagai akun dengan degree terbesar ini merupakan akun fanbase sepakbola yang membahas konten-konten (tweets) bersifat kontra, memprovokasi, dan negatif.

# %% [markdown]
# #**Kesimpulan**
#
#
# Social Network Analysis (SNA) merupakan pemodelan terhadap user yang dilambangkan dengan titik (nodes) dan interaksi antar user tersebut yang dilambangkan dengan garis (edges), hal ini dibuktikan dengan jumlah nodes dan edges masing-masing adalah 1437 dan 311. Dapat dilihat hasil SNA pada slide sebelumnya bahwa akun twitter yang paling banyak terhubung adalah akun twitter @idextratime dengan degree tertinggi yang artinya akun @idextratime merupakan akun yang paling berpengaruh bagi masyarakat indonesia mengenai Piala Dunia Qatar 2022.
#
# Berdasarkan Sentimen Analysis dari jumlah data sebanyak 2656, diantaranya yang positif yakni 1014 dan yang negatif yakni 1387. Artinya lebih banyak masyarakat Indonesia yang lebih kontra terhadap Piala Dunia Qatar 2022.
